# %% [markdown]
# ## feature generate
# ### 1.TF-IDF <br/>
# - 詞頻(term frequency，tf): 指某個字詞在該檔案中出現的次數/該檔案所有的字數量
# - 逆向檔案頻率(inverse document frequency，idf): 某字在所有檔案出現次數/所有當檔案 稱為df，idf 則是 df取倒數後對其做log10
# - tf-idf: tf * idf
# - 例子：
# >假如一篇檔案的總詞語數是100個，而詞語「母牛」出現了3次，那麼「母牛」一詞在該檔案中的詞頻就是3/100=0.03。而計算檔案頻率（IDF）的方法是以檔案集的檔案總數，除以出現「母牛」一詞的檔案數。所以，如果「母牛」一詞在1,000份檔案出現過，而檔案總數是10,000,000份的話，其逆向檔案頻率就是lg（10,000,000 / 1,000）=4。最後的tf-idf的分數為0.03 * 4=0.12。
# - 在此作業中 tf ：我們將文件數看成 wncat ， 因此 tf 就是在字詞在各類 wncat 出現的次數/各類 wncat所有的字詞數量
# - 在此作業中 df ：我們將文件數看成 wncat ， 因此 df 就是在字詞出現在幾個 wncat 中/ wncat類別總數
# - 在此作業中 idf：df 倒數取log10

# %%
import re
from collections import defaultdict, Counter

def words(text): return re.findall(r'\w+', text.lower())

TF = defaultdict(lambda: defaultdict(lambda: 0))
DF = defaultdict(lambda: [])

wncat_word_sum = defaultdict(lambda: 0)

raw_data = [line.strip().split('\t') for line in open('wn.in.evp.cat.txt', 'r') if line.strip() != '']

for wnid, wncat, senseDef, target in raw_data:
    for word in words(senseDef):
        TF[word][wncat] += 1
        wncat_word_sum[wncat] += 1 
        DF[word] += [] if wncat in DF[word] else [wncat]

# %% [markdown]
# - forsake 在 get_rid_of.v.01 類 的 TF-IDF

# %%
import math
wncat_len = len(wncat_word_sum)

def tfidf(word, wn_cat):
    tf = TF[word][wn_cat]/wncat_word_sum[wn_cat]
    idf = math.log10(wncat_len/len(DF[word]) + 1)
    return tf*idf

tfidf("forsake", "get_rid_of.v.01")
# Out:
# 0.0267668572785115

# %% [markdown]
# ### data format: ({word:tf-idf,word:tf-idf,...},'wncat')

# %%
def feature_generate(line):
    word_tfidf = {}
    for word in words(line[2]):
        word_tfidf.update({word: tfidf(word, line[1])})
    return (word_tfidf, line[1])

# %% [markdown]
# [<br/>
# 'aspirin-n-1', ( 動詞 ) <br/>
# 'medicine.n.02', ( 類別 ) <br/>
# 'aspirin acetylsalicylic_acid Bayer Empirin St._Joseph||the acetylated derivative of salicylic acid; used as an analgesic anti-inflammatory drug (trade names Bayer, Empirin, and St. Joseph) usually taken in tablet form; used as an antipyretic; slows clotting of the blood by poisoning platelets||', ( 例句,解釋 ) <br/>
# "{'aspirin-n-1': 'medicine.n.02'}" ( 多義 ) <br/>
# ]

# %%
eval("{'aspirin-n-1': 'medicine.n.02'}")
# Out:
# {'aspirin-n-1': 'medicine.n.02'}

# %% [markdown]
# ### 打散資料並extract feature  及 為 filter 做 dictionary

# %%
import random
random.shuffle(raw_data)

featuresets = []
dict_filter = defaultdict(lambda: None)

for line in raw_data:
    feature_label = feature_generate(line)
    featuresets.append(feature_label)
    dict_filter[str(feature_label)] = (line[0], eval(line[3]))

featuresets[:1]
# Out:
# [({'anywhere': 0.006294748215921136,
#    'biggest': 0.006030375237563146,
#    'cosmos': 0.00666749506573805,
#    'creation': 0.004758748147592026,
#    'everything': 0.004315281965155662,
#    'evolution': 0.0053939095960928865,
#    'existence': 0.007846905087837993,
#    'exists': 0.0053939095960928865,
#    'in': 0.008709240916855763,
#    'macrocosm': 0.007304942511847839,
#    'of': 0.01599822512316116,
#    'study': 0.0037213643314462064,
#    'that': 0.01542966146251423,
#    'the': 0.03786717480521369,
#    'they': 0.006898331523925011,
#    'tree': 0.0038166947785257055,
#    'universe': 0.009635609393287801,
#    'world': 0.011246831901807492},
#   'natural_object.n.01')]

# %%
dict_filter
# Out:
# defaultdict(<function __main__.<lambda>>,
#             {"({'universe': 0.009635609393287801, 'existence': 0.007846905087837993, 'creation': 0.004758748147592026, 'world': 0.011246831901807492, 'cosmos': 0.00666749506573805, 'macrocosm': 0.007304942511847839, 'everything': 0.004315281965155662, 'that': 0.01542966146251423, 'exists': 0.0053939095960928865, 'anywhere': 0.006294748215921136, 'they': 0.006898331523925011, 'study': 0.0037213643314462064, 'the': 0.03786717480521369, 'evolution': 0.0053939095960928865, 'of': 0.01599822512316116, 'biggest': 0.006030375237563146, 'tree': 0.0038166947785257055, 'in': 0.008709240916855763}, 'natural_object.n.01')": ('existence-n-2',
#               {'existence-n-1': 'state.n.02',
#                'existence-n-2': 'natural_object.n.01'}),
#              "({'juggle': 0.007512316454904619, 'deal': 0.021193944720575838, 'with': 0.006796710083389849, 'simultaneously': 0.003291735531723368, 'she': 0.0069126728466864466, 'had': 0.001368109883122972, 'to': 0.004054500820247753, 'her': 0.009493091021328202, 'job': 0.001955097944846724, 'and': 0.00351913994590413, 'children': 0.0017802533959809866}, 'control.v.01')": ('juggle-v-3',
#               {'juggle-v-1': 'act.v.01',
#                'juggle-v-2': 'act.v.01',
#                'juggle-v-3': 'control.v.01',
#                'juggle-v-4': 'move.v.02'}),
#              "({'mustard': 0.009487790373766018, 'mustard_greens': 0.011493109551973935, 'leaf_mustard': 0.011493109551973935, 'indian_mustard': 0.011493109551973935, 'leaves': 0.036619712107007305, 'eaten': 0.03839688255158499, 'as': 0.014935328797428125, 'cooked': 0.015803009362816332, 'greens': 0.009165272449551865}, 'vegetable.n.01')": ('mustard-n-3',
#               {'mustard-n-1': 'herb.n.01',
#                'mustard-n-2': 'flavorer.n.01',
#                'mustard-n-3': 'vegetable.n.01'}),
#              "({'flat': 0.2427892015423158, 'having': 0.06081960700657014, 'a': 0.026076198056081894, 'relatively': 0.11885995729158283, 'broad': 0.1347050736804077, 'surface': 0.10309883162491724, 'in': 0.03224126833534055, 'relation': 0.1347050736804077, 'to': 0.03054390617919974, 'depth': 0.14974194171089575, 'or': 0.024891305605393516, 'thickness': 0.1735841870395456, 'computer': 0.11337620014218475, 'monitors': 0.2298621910394787}, 'planar.a.01')": ('flat-a-2',
#               {'flat-a-1': 'even.a.03',
#                'flat-a-10': 'noneffervescent.a.02',
#                'flat-a-2': 'planar.a.01',
#                'flat-a-3': 'unqualified.a.01',
#                'flat-a-4': 'unerect.a.01',
#                'flat-a-5': 'flat.a.05',
#                'flat-a-6': 'flat.a.06',
#                'flat-a-7': 'thin.a.01',
#                'flat-a-8': 'tasteless.a.01',
#                'flat-a-9': 'unstimulating.a.01'}),
#              "({'divisor': 0.003945003278709588, 'factor': 0.005424373923163501, 'one': 0.033434906814350976, 'of': 0.02228152177818086, 'two': 0.012823539864212103, 'or': 0.006407944806880482, 'more': 0.0014005579368513521, 'integers': 0.0032566786179974885, 'that': 0.019443021156425253, 'can': 0.0013326078663898054, 'be': 0.0009936869890513175, 'exactly': 0.0028546078063225126, 'divided': 0.0023118719739200406, 'into': 0.001302241540053733, 'another': 0.003149925883282366, 'integer': 0.006291949050035605, 'what': 0.0015907115033923407, 'are': 0.00448488745846328, 'the': 0.03262810176824419, '4': 0.005271883187860639, 'factors': 0.0026359415939303196, '6': 0.00813656088474525}, 'number.n.02')": ('factor-n-3',
#               {'factor-n-1': 'happening.n.01',
#                'factor-n-2': 'idea.n.01',
#                'factor-n-3': 'number.n.02',
#                'factor-n-4': 'person.n.01',
#                'factor-n-5': 'number.n.02',
#                'factor-n-6': 'idea.n.01'}),
#              "({'reproduction': 0.004043642176216979, 'procreation': 0.00558822182429851, 'breeding': 0.0021100184810317535, 'facts_of_life': 0.002794110912149255, 'the': 0.02929356592656525, 'sexual': 0.009748469453851761, 'activity': 0.004064330935071252, 'of': 0.025765289629385204, 'conceiving': 0.002550289846862528, 'and': 0.009925457591349055, 'bearing': 0.0015675408394797122, 'offspring': 0.0056008418632782}, 'organic_process.n.01')": ('reproduction-n-5',
#               {'reproduction-n-1': 'organic_process.n.01',
#                'reproduction-n-2': 'basic_cognitive_process.n.01',
#                'reproduction-n-3': 'representation.n.02',
#                'reproduction-n-4': 'activity.n.01',
#                'reproduction-n-5': 'organic_process.n.01'}),
#              "({'green': 0.008950603650337107, 'greenness': 0.007696278717839688, 'viridity': 0.007696278717839688, 'color': 0.12669766465594046, 'or': 0.00916755675198645, 'pigment': 0.036824755377663734, 'resembling': 0.021172051777675786, 'the': 0.022413355873872474, 'of': 0.02750070841190016, 'growing': 0.004510214520549365, 'grass': 0.004798738162312019}, 'color.n.01')": ('green-n-1',
#               {'green-n-1': 'color.n.01',
#                'green-n-2': 'geographical_area.n.01',
#                'green-n-3': 'person.n.01',
#                'green-n-4': 'reformer.n.01'}),
#              "({'impersonal': 0.18569507236967353, 'neutral': 0.15912033308474016, 'having': 0.028509190784329754, 'no': 0.039068318145502524, 'personal': 0.0853555786672204, 'preference': 0.07525267856341063, 'criticism': 0.0617274559747431, 'a': 0.012223217838788387, 'observer': 0.081367587674787}, 'objective.a.01')": ('neutral-a-1',
#               {'neutral-a-1': 'objective.a.01',
#                'neutral-a-2': 'unreactive.a.01',
#                'neutral-a-3': 'nonaligned.a.01',
#                'neutral-a-4': 'neutral.a.04',
#                'neutral-a-5': 'achromatic.a.01',
#                'neutral-a-6': 'colorless.a.01'}),
#              "({'tear': 0.0013037990679655345, 'teardrop': 0.0017810173576844142, 'a': 0.0340894270003108, 'drop': 0.0055494945370533465, 'of': 0.030363890770792875, 'the': 0.017502458952464172, 'clear': 0.0008997504639895927, 'salty': 0.0015113497846754027, 'saline': 0.0019512919443079686, 'solution': 0.0011098989074106694, 'secreted': 0.0016814494385482606, 'by': 0.006487216249432008, 'lacrimal': 0.0019512919443079686, 'glands': 0.001610830284170801, 'his': 0.0009586439928584213, 'story': 0.0009940486499392244, 'brought': 0.0010480303343122616, 'tears': 0.0012563407836882244, 'to': 0.004667150349962609, 'her': 0.0005311994197701335, 'eyes': 0.0009940486499392244}, 'indefinite_quantity.n.01')": ('tear-n-1',
#               {'tear-n-1': 'indefinite_quantity.n.01',
#                'tear-n-2': 'space.n.02',
#                'tear-n-3': 'activity.n.01',
#                'tear-n-4': 'separation.n.09'}),
#              "({'lightly': 0.28797661913688744, 'without': 0.0752484254059262, 'good': 0.03876533936476295, 'reason': 0.05891467217674815, 'one': 0.030439696412232035, 'cannot': 0.053864639519749465, 'say': 0.060047921064975, 'such': 0.045079825693035036, 'things': 0.0481677716095202}, 'light.a.05')": ('lightly-r-1',
#               {'lightly-r-1': 'light.a.05',
#                'lightly-r-2': 'light.a.01',
#                'lightly-r-3': 'adv.all',
#                'lightly-r-4': 'temperate.a.02',
#                'lightly-r-5': 'light.a.05',
#                'lightly-r-6': 'adv.all',
#                'lightly-r-7': 'light.a.04'}),
#              "({'link': 0.020303605507285008, 'computing': 0.02454983691844249, 'an': 0.01093943310934655, 'instruction': 0.05946305798510069, 'that': 0.021675000625912846, 'connects': 0.02541372421544469, 'one': 0.00869705611778058, 'part': 0.03575379701898053, 'of': 0.028387828038090483, 'a': 0.0349234795393954, 'program': 0.09864098646489398, 'or': 0.020001942004334076, 'element': 0.01818583113887029, 'on': 0.007088412410165853, 'list': 0.036673088192588445, 'to': 0.008181403440857073, 'another': 0.012290335812449945}, 'code.n.03')": ('link-n-6',
#               {'link-n-1': 'relation.n.01',
#                'link-n-2': 'fastener.n.02',
#                'link-n-3': 'state.n.02',
#                'link-n-4': 'attribute.n.02',
#                'link-n-5': 'linear_unit.n.01',
#                'link-n-6': 'code.n.03'}),
#              "({'lapin': 0.002138916169722196, 'rabbit': 0.0033133437587114594, 'the': 0.018437905060313155, 'fur': 0.006460949889809389, 'of': 0.019970097391559933, 'a': 0.021110073488329325}, 'material.n.01')": ('rabbit-n-2',
#               {'rabbit-n-1': 'placental.n.01',
#                'rabbit-n-2': 'material.n.01',
#                'rabbit-n-3': 'meat.n.01'}),
#              "({'grocery_store': 0.054298155363656384, 'grocery': 0.12389990830820313, 'food_market': 0.054298155363656384, 'market': 0.07092440690803674, 'a': 0.040038256857763535, 'marketplace': 0.09911992664656251, 'where': 0.03870089672107378, 'groceries': 0.07433994498492189, 'are': 0.015432250546050814, 'sold': 0.03420405160935575, 'the': 0.012650309834954163, 'store': 0.04666012420138061, 'included': 0.03581108372938458, 'meat': 0.02933405122305422}, 'mercantile_establishment.n.01')": ('market-n-3',
#               {'market-n-1': 'activity.n.01',
#                'market-n-2': 'people.n.01',
#                'market-n-3': 'mercantile_establishment.n.01',
#                'market-n-4': 'organization.n.01',
#                'market-n-5': 'mercantile_establishment.n.01'}),
#              "({'tuna': 0.081323917489423, 'tuna_fish': 0.09851236758834801, 'tunny': 0.08991593345795314, 'important': 0.09593267218583852, 'warm': 0.054200452550850015, 'water': 0.03876349579089438, 'fatty': 0.081323917489423, 'fish': 0.10840090510170003, 'of': 0.03406539364570858, 'the': 0.02295127641484541, 'genus': 0.06417511787609818, 'thunnus': 0.08991593345795314, 'family': 0.04558905719342486, 'scombridae': 0.09851236758834801, 'usually': 0.06818517601850739, 'served': 0.05728386336215748, 'as': 0.02133618399632589, 'steaks': 0.08991593345795314}, 'saltwater_fish.n.01')": ('tuna-n-2',
#               {'tuna-n-1': 'plant.n.02',
#                'tuna-n-2': 'saltwater_fish.n.01',
#                'tuna-n-3': 'fish.n.01',
#                'tuna-n-4': 'soft-finned_fish.n.01'}),
#              "({'dark': 0.058422171241246164, 'secret': 0.2530569508896326, 'keep': 0.02622057294941978, 'it': 0.016263240043490418}, 'concealed.a.02')": ('dark-a-5',
#               {'dark-a-1': 'dark.a.01',
#                'dark-a-2': 'dark.a.02',
#                'dark-a-3': 'brunet.a.01',
#                'dark-a-4': 'evil.a.01',
#                'dark-a-5': 'concealed.a.02',
#                'dark-a-6': 'ill-natured.a.01',
#                'dark-a-7': 'unenlightened.a.01',
#                'dark-a-8': 'incomprehensible.a.02'}),
#              "({'circuit': 0.002097744605683584, 'law': 0.001359573365341345, 'a': 0.026826177203712564, 'judicial': 0.0010335590684420074, 'division': 0.00458245168896738, 'of': 0.02796075451893337, 'state': 0.004896780531333625, 'or': 0.008095181247771786, 'the': 0.019549206680786465, 'united': 0.002877301810378808, 'states': 0.0028997132056497762, 'so': 0.0005763946348459219, 'called': 0.0008502360504775221, 'because': 0.0030507406453663412, 'originally': 0.0010335590684420074, 'judges': 0.001259441200057436, 'traveled': 0.0012166290862236986, 'and': 0.007636533682611962, 'held': 0.0007772052940011546, 'court': 0.0016027321313970186, 'in': 0.007917656604475224, 'different': 0.0020881228315592004, 'locations': 0.0013146553796083082, 'one': 0.005603059162605542, 'twelve': 0.0011265156324583375, 'groups': 0.0025852516568908713, 'that': 0.003938584184531656, 'is': 0.0025394076266865673, 'covered': 0.0031396606792995414, 'by': 0.003281937070281362, 'particular': 0.00565214169149353, 'appeals': 0.001259441200057436}, 'group.n.01')": ('circuit-n-5',
#               {'circuit-n-1': 'device.n.01',
#                'circuit-n-2': 'change.n.03',
#                'circuit-n-3': 'object.n.01',
#                'circuit-n-4': 'boundary.n.01',
#                'circuit-n-5': 'group.n.01',
#                'circuit-n-6': 'facility.n.01',
#                'circuit-n-7': 'change.n.03'}),
#              "({'repeat': 0.00043724627107008, 'take_over': 0.0004563201552038528, 'do': 0.004331701536984603, 'over': 0.0009151553874474069, 'they': 0.004565036774332429, 'would': 0.001126799509503382, 'like': 0.0002563961815681837, 'to': 0.013730304828189158, 'take': 0.004629399794134807, 'it': 0.0030041105863720468, 'again': 0.0012435389301116305}, 'act.v.01')": ('repeat-v-5',
#               {'repeat-v-1': 'inform.v.01',
#                'repeat-v-2': 'produce.v.02',
#                'repeat-v-3': 'happen.v.01',
#                'repeat-v-4': 'utter.v.02',
#                'repeat-v-5': 'act.v.01',
#                'repeat-v-6': 'make.v.03'}),
#              "({'touch': 0.007386433305402489, 'deal': 0.021193944720575838, 'with': 0.006796710083389849, 'usually': 0.0015085215933298096, 'used': 0.0013014944086556651, 'a': 0.016812719353478844, 'form': 0.00173596635552986, 'of': 0.013063425291864645, 'negation': 0.0035984034287355315, 'i': 0.0053270160662209605, 'wouldn': 0.003291735531723368, 't': 0.008079438133403772, 'her': 0.009493091021328202, 'ten': 0.0026185438222670744, 'foot': 0.0023411752221615253, 'pole': 0.002996778008119406, 'the': 0.02031086408393399, 'local': 0.0024621444351341634, 'mafia': 0.0037561582274523095, 'won': 0.002159517074744428, 'gambling': 0.003154143138717922}, 'control.v.01')": ('touch-v-7',
#               {'touch-v-1': 'touch.v.01',
#                'touch-v-10': 'compete.v.01',
#                'touch-v-2': 'perceive.v.01',
#                'touch-v-3': 'affect.v.05',
#                'touch-v-4': 'refer.v.02',
#                'touch-v-5': 'touch.v.05',
#                'touch-v-6': 'change.v.01',
#                'touch-v-7': 'control.v.01',
#                'touch-v-8': 'touch.v.01',
#                'touch-v-9': 'be.v.03'}),
#              "({'clang': 0.02144903804411932, 'clangor': 0.01072451902205966, 'clangour': 0.01072451902205966, 'clangoring': 0.01072451902205966, 'clank': 0.01072451902205966, 'clash': 0.007918896825368095, 'crash': 0.007165825670591289, 'a': 0.029198853188769774, 'loud': 0.023175107468041627, 'resonant': 0.01072451902205966, 'repeating': 0.008306547650144437, 'noise': 0.052608749304144914, 'he': 0.01427242244086522, 'could': 0.0070106089070405666, 'hear': 0.012885027455136894, 'the': 0.04497450743811075, 'of': 0.027195804154686993, 'distant': 0.013511398302918136, 'bells': 0.0221332590367792}, 'sound.n.04')": ('clash-n-1',
#               {'clash-n-1': 'sound.n.04',
#                'clash-n-2': 'state.n.02',
#                'clash-n-3': 'state.n.02',
#                'clash-n-4': 'group_action.n.01'}),
#              "({'achiever': 0.0013161304955023115, 'winner': 0.0008916283976253218, 'success': 0.0010426103702074825, 'succeeder': 0.0006580652477511557, 'a': 0.028442689548718012, 'person': 0.03165316510442706, 'with': 0.0028858776531427337, 'record': 0.0005397278871044777, 'of': 0.011491665859106768, 'successes': 0.0006580652477511557, 'his': 0.0033138124511219603, 'son': 0.002699500474557269, 'would': 0.0006135621720799977, 'never': 0.0008010410169158194, 'be': 0.0009116620586639341, 'the': 0.013645047434343631, 'that': 0.0020077488889734454, 'father': 0.0053016593207265, 'was': 0.003890482080627212, 'only': 0.0005254385384080137, 'winners': 0.0005247794130862791, 'need': 0.0015085748334749008, 'apply': 0.0004236958039463866, 'if': 0.0007960388513970259, 'you': 0.003897564097004968, 'want': 0.0010794557742089554, 'to': 0.007826165482503226, 'have': 0.001737813311967879, 'dress': 0.0005430907069223448, 'like': 0.0004188367054188537}, 'person.n.01')": ('winner-n-3',
#               {'winner-n-1': 'person.n.01',
#                'winner-n-2': 'person.n.01',
#                'winner-n-3': 'person.n.01'}),
#              "({'decay': 0.01089487870185972, 'the': 0.023970219545344368, 'process': 0.05343341290562233, 'of': 0.02661100619582281, 'gradually': 0.003310049223895082, 'becoming': 0.006800126622063862, 'inferior': 0.0031954650717831486}, 'natural_process.n.01')": ('decay-n-1',
#               {'decay-n-1': 'natural_process.n.01',
#                'decay-n-2': 'process.n.06',
#                'decay-n-3': 'process.n.06',
#                'decay-n-4': 'condition.n.01'}),
#              "({'indicate': 0.014618960858682896, 'suggest': 0.0033301835570383816, 'the': 0.024692511250765665, 'necessity': 0.0015503279296418902, 'of': 0.009617328269281144, 'an': 0.004607583337095604, 'intervention': 0.0017029187740962616, 'in': 0.006167803131515441, 'medicine': 0.001248592117838837, 'tetracycline': 0.002255024764939294, 'is': 0.0042226578749840395, 'indicated': 0.004995275335557573, 'such': 0.0009434626698346117, 'cases': 0.001527693587101986}, 'inform.v.01')": ('indicate-v-5',
#               {'indicate-v-1': 'inform.v.01',
#                'indicate-v-2': 'inform.v.01',
#                'indicate-v-3': 'inform.v.01',
#                'indicate-v-4': 'express.v.02',
#                'indicate-v-5': 'inform.v.01'}),
#              "({'sedentary': 0.49256183794174, 'requiring': 0.1479477259580897, 'sitting': 0.16684596390563833, 'or': 0.02666925600577877, 'little': 0.10766114409597811, 'activity': 0.11941391366376011, 'forced': 0.16931795745874642, 'by': 0.048163492070362836, 'illness': 0.14109132794226995, 'to': 0.03272561376342829, 'lead': 0.13227640005212615, 'a': 0.027938783631516313, 'life': 0.093654641935126}, 'inactive.a.09')": ('sedentary-a-1',
#               {'sedentary-a-1': 'inactive.a.09'}),
#              "({'avaricious': 0.09712486945330086, 'covetous': 0.0886495118599538, 'grabby': 0.04856243472665043, 'grasping': 0.11617950992389686, 'greedy': 0.07522690336680103, 'prehensile': 0.0886495118599538, 'immoderately': 0.04184677687203911, 'desirous': 0.08369355374407822, 'of': 0.011195199789669487, 'acquiring': 0.0443247559299769, 'e': 0.022555723736332065, 'g': 0.022312400020934955, 'wealth': 0.031635621488217414, 'they': 0.03057288712950803, 'are': 0.027604166469696528, 'and': 0.02352371575107183, 'will': 0.036853711839910513, 'do': 0.019340132214424214, 'anything': 0.024739210766797314, 'for': 0.030628185766564446, 'money': 0.039361850569785584, 'casting': 0.04008925510041979, 'eyes': 0.024739210766797314, 'on': 0.011181720985050362, 'his': 0.01192904179845655, 'neighbor': 0.034497522438010235, 's': 0.012556352242895334, 'fields': 0.030590947566113948, 'a': 0.005509055927341245, 'old': 0.020724948343791863, 'miser': 0.04856243472665043, 'commercialism': 0.04008925510041979, 'power': 0.021781443301038855, 'grew': 0.034497522438010235, 'richer': 0.04184677687203911, 'greedier': 0.04856243472665043, 'employers': 0.04856243472665043, 'stingy': 0.0443247559299769, 'with': 0.018930273506906233, 'raises': 0.04008925510041979, 'their': 0.03291965252094946, 'employees': 0.031266960067282995}, 'acquisitive.a.01')": ('greedy-a-1',
#               {'greedy-a-1': 'acquisitive.a.01',
#                'greedy-a-2': 'desirous.a.01',
#                'greedy-a-3': 'gluttonous.a.01'}),
#              "({'imperative': 0.0008589758621885533, 'some': 0.004100483093896492, 'duty': 0.006415785500734, 'that': 0.004297532145343961, 'is': 0.004034016801531145, 'essential': 0.0012005832390373009, 'and': 0.004695924512631959, 'urgent': 0.0008342877443053534}, 'group_action.n.01')": ('imperative-n-2',
#               {'imperative-n-1': 'relation.n.01',
#                'imperative-n-2': 'group_action.n.01'}),
#              "({'civilization': 0.00611631757458876, 'civilisation': 0.003778323600172308, 'a': 0.026826177203712564, 'society': 0.005036325237025886, 'in': 0.007917656604475224, 'an': 0.005963443181732278, 'advanced': 0.0028258395894976166, 'state': 0.004896780531333625, 'of': 0.02796075451893337, 'social': 0.009245988276099763, 'development': 0.0007460041311413514, 'e': 0.0007086090200352108, 'g': 0.0007009647794187531, 'with': 0.004757697058372893, 'complex': 0.0017235011045939142, 'legal': 0.0007929588620915647, 'and': 0.007636533682611962, 'political': 0.004457048928988073, 'religious': 0.0008617505522969571, 'organizations': 0.0011816615351864762, 'the': 0.019549206680786465, 'people': 0.0231056488529863, 'slowly': 0.0009822806038836693, 'progressed': 0.0013925033942603362, 'from': 0.003691992466911362, 'barbarism': 0.0013925033942603362, 'to': 0.004662675943284916}, 'group.n.01')": ('civilization-n-1',
#               {'civilization-n-1': 'group.n.01',
#                'civilization-n-2': 'process.n.06',
#                'civilization-n-3': 'group.n.01',
#                'civilization-n-4': 'quality.n.01'}),
#              "({'declaration': 0.0068097638286615525, 'a': 0.0246883144338544, 'statement': 0.03635943247904069, 'of': 0.017898569162194206, 'taxable': 0.001176367405524456, 'goods': 0.0006472247831046574, 'or': 0.012993414389714119, 'dutiable': 0.001176367405524456, 'properties': 0.0006949208759991377}, 'statement.n.01')": ('declaration-n-3',
#               {'declaration-n-1': 'statement.n.01',
#                'declaration-n-2': 'message.n.02',
#                'declaration-n-3': 'statement.n.01',
#                'declaration-n-4': 'statement.n.01'}),
#              "({'custom': 0.0023528170716011656, 'tradition': 0.0018478491837787452, 'a': 0.017336589616689678, 'specific': 0.0012612559723067837, 'practice': 0.0021079354047498413, 'of': 0.01851473205502016, 'long': 0.0010047336532256978, 'standing': 0.001143290893175848}, 'cognition.n.01')": ('custom-n-2',
#               {'custom-n-1': 'activity.n.01',
#                'custom-n-2': 'cognition.n.01',
#                'custom-n-3': 'relation.n.01',
#                'custom-n-4': 'activity.n.01'}),
#              "({'ardent': 0.06776993124118583, 'warm': 0.04516704379237501, 'characterized': 0.016852017821139945, 'by': 0.008027248678393807, 'strong': 0.01879260589855285, 'enthusiasm': 0.05940302911252086, 'revolutionaries': 0.03537048997517591, 'support': 0.02051986267419027}, 'enthusiastic.a.01')": ('warm-a-7',
#               {'warm-a-1': 'warm.a.01',
#                'warm-a-2': 'warm.a.02',
#                'warm-a-3': 'warm.a.03',
#                'warm-a-4': 'loving.a.01',
#                'warm-a-5': 'fresh.a.01',
#                'warm-a-6': 'excitable.a.01',
#                'warm-a-7': 'enthusiastic.a.01',
#                'warm-a-8': 'lively.a.01'}),
#              "({'transfer': 0.00041453521847391745, 'transferee': 0.00032903262387557787, 'someone': 0.01937470308045272, 'who': 0.0502845389304638, 'transfers': 0.00032903262387557787, 'or': 0.009263869821646599, 'is': 0.011432665646340828, 'transferred': 0.00025484827459885836, 'from': 0.0023887497781905753, 'one': 0.003346362273775294, 'position': 0.0011074398756104633, 'to': 0.007826165482503226, 'another': 0.0038094294034581, 'the': 0.013645047434343631, 'best': 0.0010008794368645464, 'student': 0.0010603318641452999, 'was': 0.003890482080627212, 'a': 0.028442689548718012, 'lsu': 0.00032903262387557787}, 'person.n.01')": ('transfer-n-2',
#               {'transfer-n-1': 'change.n.03',
#                'transfer-n-2': 'person.n.01',
#                'transfer-n-3': 'change.n.03',
#                'transfer-n-4': 'writing.n.02'}),
#              "({'draw': 0.006204769791306758, 'get': 0.0016362592548788395, 'earn': 0.0008621731144348291, 'or': 0.011497805072690052, 'achieve': 0.0007191911513887716, 'a': 0.01722583282181569, 'base': 0.0011363254740819502, 'by': 0.006251685063437826, 'being': 0.001222538212691922, 'walked': 0.0007049003832521649, 'the': 0.01908489831019223, 'pitcher': 0.0008621731144348291, 'he': 0.004178346188917206, 'drew': 0.0018172884969495224, 'on': 0.0035489005179373417, 'balls': 0.0021554327860870727}, 'make.v.03')": ('get-v-31',
#               {'get-v-1': 'get.v.01',
#                'get-v-10': 'induce.v.02',
#                'get-v-11': 'take.v.04',
#                'get-v-12': 'change.v.02',
#                'get-v-13': 'change.v.02',
#                'get-v-14': 'communicate.v.02',
#                'get-v-15': 'change.v.01',
#                'get-v-16': 'convey.v.01',
#                'get-v-17': 'understand.v.01',
#                'get-v-18': 'move.v.02',
#                'get-v-19': 'touch.v.01',
#                'get-v-2': 'change.v.02',
#                'get-v-20': 'get.v.20',
#                'get-v-21': 'get.v.01',
#                'get-v-22': 'get.v.01',
#                'get-v-23': 'perceive.v.01',
#                'get-v-24': 'perceive.v.01',
#                'get-v-25': 'get.v.25',
#                'get-v-26': 'leave.v.01',
#                'get-v-27': 'enter.v.01',
#                'get-v-28': 'displease.v.01',
#                'get-v-29': 'affect.v.05',
#                'get-v-3': 'change.v.01',
#                'get-v-30': 'make.v.03',
#                'get-v-31': 'make.v.03',
#                'get-v-32': 'destroy.v.02',
#                'get-v-33': 'be.v.01',
#                'get-v-34': 'get_down.v.07',
#                'get-v-35': 'change.v.02',
#                'get-v-36': 'make.v.03',
#                'get-v-4': 'change.v.02',
#                'get-v-5': 'arrive.v.01',
#                'get-v-6': 'move.v.02',
#                'get-v-7': 'change.v.02',
#                'get-v-8': 'punish.v.01',
#                'get-v-9': 'gain.v.05'}),
#              "({'prepare': 0.0038324157897939772, 'groom': 0.000657637343904702, 'train': 0.0026575502521833526, 'educate': 0.0024871858533130156, 'for': 0.005547894288578045, 'a': 0.01356511140205169, 'future': 0.00045958705431217413, 'role': 0.0004759264713277879, 'or': 0.013439876202864354, 'function': 0.0009647146159913596, 'he': 0.004024110815763361, 'is': 0.0017158159639774101, 'grooming': 0.0007527045374380196, 'his': 0.004456628387751526, 'son': 0.0007249136947642127, 'to': 0.012437455218868108, 'become': 0.002609983607065088, 'successor': 0.000657637343904702, 'the': 0.02617768462169195, 'prince': 0.0009581039474484943, 'was': 0.003537078060289134, 'prepared': 0.0007036084798115233, 'king': 0.0004759264713277879, 'one': 0.003261656061392, 'day': 0.0013725505168654401, 'they': 0.0010383520622793926, 'trained': 0.001312655168808313, 'him': 0.0010344569625239783, 'be': 0.003738981992766163, 'warrior': 0.0007527045374380196}, 'change.v.01')": ('train-v-4',
#               {'train-v-1': 'inform.v.01',
#                'train-v-2': 'learn.v.04',
#                'train-v-3': 'change.v.01',
#                'train-v-4': 'change.v.01',
#                'train-v-5': 'change.v.01',
#                'train-v-6': 'put.v.01',
#                'train-v-7': 'inform.v.01',
#                'train-v-8': 'exercise.v.04'}),
#              "({'furthermore': 0.0012395502105235047, 'moreover': 0.0009916401684188037, 'what_is_more': 0.0004958200842094018, 'in': 0.010397044038251535, 'addition': 0.0013080263542225602, 'their': 0.0015124861921833983, 'quality': 0.00046755120013345595, 'is': 0.00737602240430476, 'improving': 0.00038403150266342196, 'mice': 0.0004958200842094018, 'nested': 0.00045255359088702325, 'there': 0.002510259600000147, 'computer': 0.0003668341247050844, 'chess': 0.00032700658855564006, 'games': 0.00029532541541342434, 'are': 0.002536534710114478, 'getting': 0.0006459962972860041, 'cheaper': 0.00042725354586062357, 'all': 0.00613579534859938, 'the': 0.018800144992531374, 'time': 0.007952759107765751, 'cellar': 0.0004093093345024166, 'was': 0.008276579550909517, 'dark': 0.0002604382094447269, 'what': 0.001499441171230485, 'more': 0.0038725809620042853, 's': 0.0033972931758710916, 'no': 0.0021573532021675252, 'sign': 0.0002883139513482186, 'of': 0.003886283044616356, 'a': 0.012177516995560246, 'change': 0.0006693963755880503}, 'adv.all')": ('furthermore-r-1',
#               {'furthermore-r-1': 'adv.all'}),
#              "({'slightly': 0.0013435970633758623, 'somewhat': 0.0012813831827359, 'more_or_less': 0.0014874602526282056, 'to': 0.011463847444307064, 'a': 0.012177516995560246, 'small': 0.00037068186418694725, 'degree': 0.005428999251451013, 'or': 0.00987920671137275, 'extent': 0.004697450252997757, 'his': 0.002618591070656302, 'arguments': 0.0003661094807816857, 'were': 0.003257715150728825, 'self': 0.000251371287961451, 'contradictory': 0.00038403150266342196, 'the': 0.018800144992531374, 'children': 0.0021262431090480417, 'argued': 0.0010232733362560416, 'because': 0.0003718007904728177, 'one': 0.0016808805611586285, 'slice': 0.0003408759569201107, 'of': 0.003886283044616356, 'cake': 0.0003522180174142546, 'was': 0.008276579550909517, 'larger': 0.0004324709270223279, 'than': 0.0020966668082897876, 'other': 0.0018951431781007266}, 'adv.all')": ('somewhat-r-1',
#               {'somewhat-r-1': 'adv.all', 'somewhat-r-2': 'adv.all'}),
#              "({'drown': 0.012250252612483654, 'get': 0.006476412778157399, 'rid': 0.011046264743252937, 'of': 0.009115357626909789, 'as': 0.010276602383551462, 'if': 0.01913231909126017, 'by': 0.0061861365961933925, 'submerging': 0.014436044362515412, 'she': 0.004180370200098608, 'drowned': 0.011943866080702678, 'her': 0.004305639333641403, 'trouble': 0.008701907519631883, 'in': 0.0022184358946335243, 'alcohol': 0.009501230107400256}, 'unmake.v.01')": ('drown-v-2',
#               {'drown-v-1': 'touch.v.05',
#                'drown-v-2': 'unmake.v.01',
#                'drown-v-3': 'change.v.02',
#                'drown-v-4': 'kill.v.01',
#                'drown-v-5': 'be.v.01'}),
#              "({'sad': 0.2653004452951908, 'of': 0.013247653084442226, 'things': 0.02568947819174411, 'that': 0.01348666705612355, 'make': 0.020836436344268013, 'you': 0.018908599153942156, 'feel': 0.030348650192789477, 'news': 0.029274732740710154, 'she': 0.03037735678738322, 'doesn': 0.033415586961258535, 't': 0.021302785211741282, 'like': 0.02438327686713427, 'movies': 0.03839688255158499, 'it': 0.016805348044940098, 'was': 0.01332299402708907, 'a': 0.013038099028040947, 'very': 0.020478393271035088, 'story': 0.029274732740710154, 'when': 0.020213068881228313, 'i': 0.017556957118253246, 'am': 0.03202555790132, 'dead': 0.029418428193809378, 'my': 0.020250306923398863, 'dearest': 0.04951868596524627, 'sing': 0.03950752340704083, 'no': 0.020836436344268013, 'songs': 0.0415821203787646, 'for': 0.012081117719033753, 'me': 0.024176796784420924, 'christina': 0.052450961183805996, 'rossetti': 0.052450961183805996}, 'sorrowful.a.01')": ('sad-a-2',
#               {'sad-a-1': 'sad.a.01',
#                'sad-a-2': 'sorrowful.a.01',
#                'sad-a-3': 'bad.a.01'}),
#              "({'whole': 0.0043495979436210044, 'unit': 0.002222439802563916, 'an': 0.005483068181739198, 'assemblage': 0.001157989061078033, 'of': 0.019645116148410052, 'parts': 0.0027797852011763103, 'that': 0.008724084873570563, 'is': 0.009047543649596262, 'regarded': 0.0011885005582940133, 'as': 0.0027342953453387536, 'a': 0.026495241922320802, 'single': 0.0006888696647114809, 'entity': 0.002598208898398948, 'how': 0.0006588635212590285, 'big': 0.0007408132675213053, 'part': 0.010317884466556898, 'compared': 0.0010150232801976714, 'to': 0.006710215352631351, 'the': 0.034314866079966186, 'team': 0.0007329047743954975}, 'object.n.01')": ('unit-n-6',
#               {'unit-n-1': 'unit_of_measurement.n.01',
#                'unit-n-2': 'relation.n.01',
#                'unit-n-3': 'organization.n.01',
#                'unit-n-4': 'idea.n.01',
#                'unit-n-5': 'unit.n.05',
#                'unit-n-6': 'object.n.01'}),
#              "({'attention': 0.0008204230347345277, 'a': 0.025219680601685043, 'general': 0.005055866776005704, 'interest': 0.00038141103985097084, 'that': 0.014963309434531237, 'leads': 0.0006335189308012613, 'people': 0.001270529596295597, 'to': 0.00702286893901308, 'want': 0.001376109131135723, 'know': 0.0009174060874238155, 'more': 0.000297831541802453, 'she': 0.001330395187768608, 'was': 0.008557835579444074, 'the': 0.021108473199054904, 'center': 0.0004316078549402046, 'of': 0.020886810702478255}, 'idea.n.01')": ('attention-n-3',
#               {'attention-n-1': 'basic_cognitive_process.n.01',
#                'attention-n-2': 'activity.n.01',
#                'attention-n-3': 'idea.n.01',
#                'attention-n-4': 'act.n.02',
#                'attention-n-5': 'cognition.n.01',
#                'attention-n-6': 'property.n.02'}),
#              "({'better': 0.09583784271407203, 'best': 0.09200189139389107, 'comparative': 0.0644558971868086, 'and': 0.0366268381211864, 'superlative': 0.06565597954541778, 'of': 0.010458673487717545, 'well': 0.07317272915604767, 'wiser': 0.09073507541032053, 'or': 0.014738273055825108, 'more': 0.032212832547581095, 'advantageous': 0.11235541232091335, 'hence': 0.11235541232091335, 'advisable': 0.12422596069848788, 'it': 0.06633690017739512, 'would': 0.0634491908015753, 'be': 0.03428220112227045, 'to': 0.04219881774757859, 'speak': 0.053600344409301906, 'him': 0.03251928240836656, 'the': 0.010569666769994596, 'white': 0.04245759799431447, 'house': 0.03872292980024269, 'thought': 0.041252615099670785, 'not': 0.0208210225525598, 'respond': 0.06565597954541778}, 'advisable.a.01')": ('better-a-3',
#               {'better-a-1': 'better.a.01',
#                'better-a-2': 'better.a.02',
#                'better-a-3': 'advisable.a.01',
#                'better-a-4': 'major.a.03',
#                'better-a-5': 'good.a.01',
#                'better-a-6': 'ample.a.01',
#                'better-a-7': 'good.a.03',
#                'better-a-8': 'reputable.a.01'}),
#              "({'flash': 0.03415314099657065, 'appear': 0.03214766111495272, 'briefly': 0.018523736261762618, 'the': 0.03398554392198263, 'headlines': 0.022854778137805974, 'flashed': 0.04570955627561195, 'on': 0.012213879845208856, 'screen': 0.017492337052430165}, 'appear.v.02')": ('flash-v-2',
#               {'flash-v-1': 'cause_to_be_perceived.v.01',
#                'flash-v-2': 'appear.v.02',
#                'flash-v-3': 'show.v.04',
#                'flash-v-4': 'convey.v.01',
#                'flash-v-5': 'travel.v.01',
#                'flash-v-6': 'show.v.04',
#                'flash-v-7': 'cover.v.01',
#                'flash-v-8': 'appear.v.02'}),
#              "({'confirm': 0.015318671526891606, 'corroborate': 0.012034637365309214, 'sustain': 0.009366440126572569, 'substantiate': 0.011361839992025913, 'support': 0.006591466403946397, 'affirm': 0.011361839992025913, 'establish': 0.046172331830717506, 'or': 0.013564095788789967, 'strengthen': 0.009957027937258828, 'as': 0.00999496191032475, 'with': 0.0025698841663295267, 'new': 0.004716540899172304, 'evidence': 0.014601126945893548, 'facts': 0.01074860694249316, 'his': 0.0032388602970952773, 'story': 0.006716955886969825, 'confirmed': 0.009957027937258828, 'my': 0.00464634193271102, 'doubts': 0.010884654348488738, 'the': 0.04838199282479362, 'supports': 0.00973585211990762, 'defendant': 0.00893247990316993}, 'confirm.v.01')": ('support-v-5',
#               {'support-v-1': 'support.v.01',
#                'support-v-10': 'make.v.03',
#                'support-v-11': 'act.v.01',
#                'support-v-2': 'give.v.03',
#                'support-v-3': 'act.v.01',
#                'support-v-4': 'hold.v.10',
#                'support-v-5': 'confirm.v.01',
#                'support-v-6': 'agree.v.01',
#                'support-v-7': 'equal.v.01',
#                'support-v-8': 'express.v.02',
#                'support-v-9': 'make.v.03'}),
#              "({'jamming': 0.0010771424134933397, 'electronic_jamming': 0.0010771424134933397, 'jam': 0.0007651746620114735, 'deliberate': 0.0007794211879805923, 'radiation': 0.0006858120913199072, 'or': 0.009564606652494229, 'reflection': 0.0007197166363933456, 'of': 0.02383832607509754, 'electromagnetic': 0.0008342877443053534, 'energy': 0.0005360360718099797, 'for': 0.010190258619616099, 'the': 0.029486761716979615, 'purpose': 0.0018776721971163527, 'disrupting': 0.0009281853039408861, 'enemy': 0.0036257645659193345, 'use': 0.0012655452764084995, 'electronic': 0.0006935189518203975, 'devices': 0.0007522916944795814, 'systems': 0.0008589758621885533}, 'group_action.n.01')": ('jam-n-4',
#               {'jam-n-1': 'sweet.n.03',
#                'jam-n-2': 'condition.n.01',
#                'jam-n-3': 'gathering.n.01',
#                'jam-n-4': 'group_action.n.01'}),
#              "({'style': 0.00040400679597815583, 'editorial': 0.0017481748656597684, 'directions': 0.004573034443349469, 'to': 0.011849833136585846, 'be': 0.0025841775165028765, 'followed': 0.0007819537679665108, 'in': 0.004870505173111642, 'spelling': 0.0005511754895923872, 'and': 0.00242111028825787, 'punctuation': 0.0006293389184860515, 'capitalization': 0.0007891812464161549, 'typographical': 0.0007891812464161549, 'display': 0.0004521122891260653}, 'message.n.02')": ('style-n-6',
#               {'style-n-1': 'property.n.02',
#                'style-n-2': 'expressive_style.n.01',
#                'style-n-3': 'idea.n.01',
#                'style-n-4': 'basic_cognitive_process.n.01',
#                'style-n-5': 'reproductive_structure.n.01',
#                'style-n-6': 'message.n.02',
#                'style-n-7': 'quality.n.01',
#                'style-n-8': 'tool.n.01',
#                'style-n-9': 'body_part.n.01'}),
#              "({'complete': 0.08624225278469672, 'fill_out': 0.16418727931391333, 'fill_in': 0.14985988909658854, 'make_out': 0.1271692890248303, 'write': 0.09950466535580604, 'all': 0.052774670196858484, 'the': 0.019126063679037842, 'required': 0.0954731056035958, 'information': 0.0751704235942114, 'onto': 0.09779490184690252, 'a': 0.03725171150868842, 'form': 0.13077613211658276, 'fill': 0.10342653700924238, 'out': 0.10686065980674053, 'this': 0.05222024458708731, 'questionnaire': 0.14985988909658854, 'please': 0.08624225278469672, 'make': 0.05953267526933718}, 'complete.v.05')": ('complete-v-5',
#               {'complete-v-1': 'change.v.01',
#                'complete-v-2': 'change.v.01',
#                'complete-v-3': 'change.v.01',
#                'complete-v-4': 'play.v.01',
#                'complete-v-5': 'complete.v.05'}),
#              "({'harm': 0.0012385004564776701, 'cause': 0.008251103151844916, 'or': 0.013439876202864354, 'do': 0.0013137042690496237, 'to': 0.012437455218868108, 'these': 0.0009278048305507656, 'pills': 0.0012370005497221407, 'won': 0.00020427864220555402, 't': 0.002904230464169465, 'your': 0.00601470033392449, 'system': 0.0005683498211503403}, 'change.v.01')": ('harm-v-1',
#               {'harm-v-1': 'change.v.01'}),
#              "({'harebrained': 0.05051916286581949, 'insane': 0.04353291073867804, 'mad': 0.038150370777922105, 'very': 0.009001491547707732, 'foolish': 0.058693518011460145, 'ideas': 0.012745456845929213, 'took': 0.011647319193183958, 'risks': 0.019564506003820047, 'behind': 0.013646243609259655, 'the': 0.011769885340946364, 'wheel': 0.01559559822286841, 'a': 0.0315206789688902, 'completely': 0.013413813958610733, 'scheme': 0.016263400474557453, 'to': 0.015104129429274598, 'build': 0.01665936862136206, 'bridge': 0.016263400474557453, 'between': 0.010316340192094946, 'two': 0.009123137029972632, 'mountains': 0.016263400474557453}, 'foolish.a.01')": ('mad-a-4',
#               {'mad-a-1': 'angry.a.01',
#                'mad-a-2': 'insane.a.01',
#                'mad-a-3': 'wild.a.01',
#                'mad-a-4': 'foolish.a.01'}),
#              "({'circumstance': 0.0018478491837787452, 'condition': 0.0012665573468518855, 'consideration': 0.0031252631662214343, 'information': 0.004763723562364208, 'that': 0.014499057378329731, 'should': 0.0026901536920011203, 'be': 0.00311225313847344, 'kept': 0.0010140062400944565, 'in': 0.004560722604961413, 'mind': 0.007305880337485332, 'when': 0.0011437043878476977, 'making': 0.0009459419792300877, 'a': 0.017336589616689678, 'decision': 0.001381354662655877, 'another': 0.0023366009994246597, 'is': 0.009200682857157479, 'the': 0.022801932952696755, 'time': 0.0031070122703421525, 'it': 0.0043740815356501945, 'would': 0.0009094942476272581, 'take': 0.0015733102836268267}, 'cognition.n.01')": ('condition-n-4',
#               {'condition-n-1': 'condition.n.01',
#                'condition-n-2': 'statement.n.01',
#                'condition-n-3': 'state.n.02',
#                'condition-n-4': 'cognition.n.01',
#                'condition-n-5': 'condition.n.01',
#                'condition-n-6': 'illness.n.01',
#                'condition-n-7': 'statement.n.01',
#                'condition-n-8': 'activity.n.01'}),
#              "({'brilliantly': 0.08563422234090774, 'brightly': 0.038725674994963336, 'bright': 0.09274077372338681, 'with': 0.009143193326464915, 'brightness': 0.033944588064297634, 'the': 0.03278753773549344, 'stars': 0.031780183601073965, 'shone': 0.038725674994963336, 'windows': 0.031780183601073965, 'glowed': 0.04281711117045387, 'jewel': 0.03633408257852294}, 'bright.a.01')": ('brightly-r-1',
#               {'brightly-r-1': 'bright.a.01'}),
#              "({'surprisingly': 0.08011577863363643, 'in': 0.01860073173192724, 'a': 0.015043960416970323, 'surprising': 0.1370882869653146, 'manner': 0.026923115231176763, 'he': 0.017648399287454493, 'was': 0.018447222499046408, 'friendly': 0.015797637990653486}, 'surprising.a.01')": ('surprisingly-r-1',
#               {'surprisingly-r-1': 'surprising.a.01',
#                'surprisingly-r-2': 'surprising.a.01'}),
#              "({'isolation': 0.0010037158798958576, 'a': 0.017964973823379898, 'feeling': 0.017614108974593156, 'of': 0.023110926433533154, 'being': 0.011228719648886182, 'disliked': 0.0005264252058981739, 'and': 0.0052128084217418855, 'alone': 0.0006072421462995131}, 'state.n.02')": ('isolation-n-2',
#               {'isolation-n-1': 'state.n.02',
#                'isolation-n-2': 'state.n.02',
#                'isolation-n-3': 'group_action.n.01',
#                'isolation-n-4': 'cognition.n.01',
#                'isolation-n-5': 'group_action.n.01'}),
#              "({'spot': 0.002275423541898779, 'speckle': 0.0011093735088777929, 'dapple': 0.0011093735088777929, 'patch': 0.004013718183278436, 'fleck': 0.0019119183770365355, 'maculation': 0.0011093735088777929, 'a': 0.031085043049479864, 'small': 0.0037322225148012033, 'contrasting': 0.0027474296449129395, 'part': 0.0038652753534033006, 'of': 0.018094043546800914, 'something': 0.005022922841856964, 'bald': 0.0008846788078718015, 'leopard': 0.0009559591885182678, 's': 0.002007885155958488, 'spots': 0.0013270182118077024, 'clouds': 0.0006988279527651512, 'patches': 0.0014339387827774018, 'thin': 0.002651040934387594, 'ice': 0.001577534885291709, 'red': 0.0017388802465870012}, 'artifact.n.01')": ('patch-n-1',
#               {'patch-n-1': 'artifact.n.01',
#                'patch-n-2': 'geographical_area.n.01',
#                'patch-n-3': 'piece_of_cloth.n.01',
#                'patch-n-4': 'time_period.n.01',
#                'patch-n-5': 'program.n.07',
#                'patch-n-6': 'artifact.n.01',
#                'patch-n-7': 'artifact.n.01',
#                'patch-n-8': 'artifact.n.01',
#                'patch-n-9': 'artifact.n.01'}),
#              "({'wellbeing': 0.0010194952293294444, 'well': 0.0015073034095815065, 'being': 0.011228719648886182, 'welfare': 0.0004918050902278486, 'upbeat': 0.0012407087210835246, 'eudaemonia': 0.0006796634862196295, 'eudaimonia': 0.0006796634862196295, 'a': 0.017964973823379898, 'contented': 0.0012407087210835246, 'state': 0.021814949735489832, 'of': 0.023110926433533154, 'happy': 0.0018535759661193912, 'and': 0.0052128084217418855, 'healthy': 0.0006422109039604052, 'prosperous': 0.0005420031016884603, 'the': 0.021416440908490923, 'town': 0.0003397730070238484, 'was': 0.0066181637981991845, 'finally': 0.00037877655708243644, 'on': 0.002816920839521853, 'after': 0.000526240261006087, 'our': 0.0006685996218614741, 'recent': 0.0006906692769600641, 'troubles': 0.0010840062033769205}, 'state.n.02')": ('well-being-n-1',
#               {'well-being-n-1': 'state.n.02'}),
#              "({'mission': 0.002122548182050563, 'charge': 0.001357881440393265, 'commission': 0.0004978663440569419, 'a': 0.01786540414916125, 'special': 0.0006313354346982923, 'assignment': 0.0011865796650614479, 'that': 0.005958874146721254, 'is': 0.0056839602568802385, 'given': 0.0008828741026165769, 'to': 0.009779858102680006, 'person': 0.002136186301083497, 'or': 0.01051059045417903, 'group': 0.0013676471301585793, 'confidential': 0.0004651243890242125, 'london': 0.00044191860634273857, 'his': 0.007263283093541965, 'was': 0.006259124710712986, 'deliver': 0.0003931300292114715, 'message': 0.0004138617011142976}, 'activity.n.01')": ('mission-n-3',
#               {'mission-n-1': 'organization.n.01',
#                'mission-n-2': 'activity.n.01',
#                'mission-n-3': 'activity.n.01',
#                'mission-n-4': 'activity.n.01',
#                'mission-n-5': 'organization.n.01'}),
#              "({'say': 0.010675185967106668, 'communicate': 0.004266320283509444, 'or': 0.011754227646991381, 'express': 0.035821211035517865, 'nonverbally': 0.0063850608622077415, 'what': 0.023171364232748428, 'does': 0.006637359364173838, 'this': 0.01827708560548056, 'painting': 0.0035353654595844104, 'did': 0.0030459577622280426, 'his': 0.006273792353262335, 'face': 0.0028543864657493453, 'anything': 0.0032527480823011283, 'about': 0.0023768100904155752, 'how': 0.002999049139360541, 'he': 0.0028324591449001035, 'felt': 0.0030339591873928214}, 'convey.v.01')": ('say-v-7',
#               {'say-v-1': 'express.v.02',
#                'say-v-10': 'utter.v.02',
#                'say-v-11': 'inform.v.01',
#                'say-v-2': 'insist.v.01',
#                'say-v-3': 'think.v.03',
#                'say-v-4': 'have.v.02',
#                'say-v-5': 'request.v.01',
#                'say-v-6': 'pronounce.v.01',
#                'say-v-7': 'convey.v.01',
#                'say-v-8': 'express.v.02',
#                'say-v-9': 'say.v.09'}),
#              "({'knee': 0.0007880708150253303, 'the': 0.01809222239908985, 'part': 0.0038652753534033006, 'of': 0.018094043546800914, 'a': 0.031085043049479864, 'trouser': 0.0004779795942591339, 'leg': 0.0013834200107566183, 'that': 0.013668919313638733, 'provides': 0.0032254427568782365, 'cloth': 0.0038044050295807006, 'covering': 0.011301539928396194, 'for': 0.008745982904705903}, 'artifact.n.01')": ('knee-n-3',
#               {'knee-n-1': 'body_part.n.01',
#                'knee-n-2': 'body_part.n.01',
#                'knee-n-3': 'artifact.n.01'}),
#              "({'bush': 0.00024295498896419914, 'vannevar_bush': 0.00032903262387557787, 'united': 0.0029475937526879, 'states': 0.002814207777598838, 'electrical': 0.0004236958039463866, 'engineer': 0.0007454230763221253, 'who': 0.0502845389304638, 'designed': 0.0001799092957014926, 'an': 0.0074244916760828955, 'early': 0.0005501097835898082, 'analogue': 0.00030032041903123964, 'computer': 0.0006491623254634111, 'and': 0.005950332018084525, 'led': 0.000621802827710876, 'the': 0.013645047434343631, 'scientific': 0.00041453521847391745, 'program': 0.0003514263601510363, 'of': 0.011491665859106768, 'during': 0.0007669527150999972, 'world': 0.00043421575049307887, 'war': 0.00044127360191945216, 'ii': 0.00024295498896419914, '1890': 0.00030032041903123964, '1974': 0.00032903262387557787}, 'person.n.01')": ('bush-n-5',
#               {'bush-n-1': 'shrub.n.01',
#                'bush-n-2': 'geographical_area.n.01',
#                'bush-n-3': 'collection.n.01',
#                'bush-n-4': 'representative.n.01',
#                'bush-n-5': 'person.n.01',
#                'bush-n-6': 'representative.n.01',
#                'bush-n-7': 'hair.n.01'}),
#              "({'achieve': 0.03510233983343984, 'accomplish': 0.023270837910051512, 'attain': 0.03888297402840185, 'reach': 0.03934457067052774, 'to': 0.012958020803296862, 'gain': 0.01607958445754732, 'with': 0.010861005405982565, 'effort': 0.01532942092347273, 'she': 0.022092623118096885, 'achieved': 0.019792517924030115, 'her': 0.013273546713407637, 'goal': 0.03765942115296828, 'despite': 0.019792517924030115, 'setbacks': 0.027862083762361052}, 'succeed.v.01')": ('achieve-v-1',
#               {'achieve-v-1': 'succeed.v.01'}),
#              "({'rap': 0.002371603823883913, 'voluble': 0.0032775027239469396, 'conversation': 0.014771558130646052}, 'speech.n.02')": ('rap-n-4',
#               {'rap-n-1': 'message.n.02',
#                'rap-n-2': 'happening.n.01',
#                'rap-n-3': 'sound.n.04',
#                'rap-n-4': 'speech.n.02'}),
# ...
#               {'length-n-1': 'property.n.02',
#                'length-n-2': 'property.n.02',
#                'length-n-3': 'property.n.02',
#                'length-n-4': 'property.n.02',
#                'length-n-5': 'object.n.01'}),
#              "({'swim': 0.004049457636031751, 'travel': 0.023386925752825173, 'through': 0.008991532528815706, 'water': 0.002664157786315765, 'we': 0.007964624368125794, 'had': 0.0007968887463551331, 'to': 0.01102099707496898, 'for': 0.0021351018060148017, '20': 0.0005581747218497597, 'minutes': 0.0005513326278015308, 'reach': 0.0004780452253782825, 'the': 0.03864647918650946, 'shore': 0.0023643453255072556, 'a': 0.007488746128035301, 'big': 0.0004469609748569879, 'fish': 0.00046563962672551557, 'was': 0.0021583642753752546, 'swimming': 0.0005910863313768139, 'in': 0.010090234935581541, 'tank': 0.0006012086630090149}, 'travel.v.01')": ('swim-v-1',
#               {'swim-v-1': 'travel.v.01',
#                'swim-v-2': 'travel.v.01',
#                'swim-v-3': 'be.v.01',
#                'swim-v-4': 'be.v.01'}),
#              "({'union': 0.0018705642903817268, 'unification': 0.0002928366999718881, 'the': 0.021416440908490923, 'state': 0.021814949735489832, 'of': 0.023110926433533154, 'being': 0.011228719648886182, 'joined': 0.0008475595098426118, 'or': 0.009604717272335464, 'united': 0.00016022822027045403, 'linked': 0.00024140785463224194, 'there': 0.0025807725101125107, 'is': 0.006010006469131795, 'strength': 0.0007140103719608245, 'in': 0.00943786388290572}, 'state.n.02')": ('union-n-4',
#               {'union-n-1': 'organization.n.01',
#                'union-n-2': 'country.n.02',
#                'union-n-3': 'organic_process.n.01',
#                'union-n-4': 'state.n.02',
#                'union-n-5': 'state.n.02',
#                'union-n-6': 'organic_process.n.01'}),
#              "({'deal': 0.0007304753932015463, 'the': 0.029296629306008553, 'type': 0.0003993751152065632, 'of': 0.020884535450767745, 'treatment': 0.0003767712694272941, 'received': 0.0007746190553693252, 'especially': 0.002217518711001631, 'as': 0.0033677702190279104, 'result': 0.002513117497539717, 'an': 0.015255146720327973, 'agreement': 0.0015070850777091764, 'he': 0.006148102496871401, 'got': 0.002559934729091262, 'a': 0.02285502064915413, 'good': 0.001459401011379311, 'on': 0.0026463406331285856, 'his': 0.0033214194811388826, 'car': 0.00029739521891614204}, 'happening.n.01')": ('deal-n-7',
#               {'deal-n-1': 'group_action.n.01',
#                'deal-n-2': 'statement.n.01',
#                'deal-n-3': 'indefinite_quantity.n.01',
#                'deal-n-4': 'artifact.n.01',
#                'deal-n-5': 'wood.n.01',
#                'deal-n-6': 'collection.n.01',
#                'deal-n-7': 'happening.n.01',
#                'deal-n-8': 'act.n.02'}),
#              "({'pass': 0.013242696488514625, 'hand': 0.02251907963198012, 'reach': 0.011803371201158321, 'pass_on': 0.016664131726457934, 'turn_over': 0.01725052795230185, 'give': 0.03431683629032134, 'place': 0.00822255971322002, 'into': 0.008622417469749717, 'the': 0.032862054866710476, 'hands': 0.01097628671805231, 'or': 0.010182806838570075, 'custody': 0.014594458872903879, 'of': 0.005419494443635455, 'me': 0.024176796784420924, 'spoon': 0.01725052795230185, 'please': 0.02195257343610462, 'turn': 0.013179961056585891, 'files': 0.014366372148014847, 'over': 0.019779835760510997, 'to': 0.0208253905767271, 'he': 0.011587332865500424, 'turned': 0.012151122531366739, 'prisoner': 0.014844388443022587, 'his': 0.014116032794840251, 'lawyers': 0.01725052795230185}, 'transfer.v.05')": ('hand-v-1',
#               {'hand-v-1': 'transfer.v.05', 'hand-v-2': 'lead.v.01'}),
#              "({'glazed': 0.44489456330221683, 'shiny': 0.2519770457025662, 'having': 0.029428842099953292, 'a': 0.025235030376853443, 'surface': 0.049886531431411564, 'or': 0.012044180131642023, 'coating': 0.16425324705521566, 'fabrics': 0.1015179893880116, 'doughnuts': 0.11122364082555421}, 'glazed.a.03')": ('shiny-a-2',
#               {'shiny-a-1': 'bright.a.01',
#                'shiny-a-2': 'glazed.a.03',
#                'shiny-a-3': 'polished.a.01'}),
#              "({'trip': 0.0008751354071041082, 'a': 0.016816928253103883, 'hallucinatory': 0.000752495169269354, 'experience': 0.0007593866693449749, 'induced': 0.000621199718928373, 'by': 0.002796047335381169, 'drugs': 0.0014075740048335563, 'an': 0.004813159569716859, 'acid': 0.0005097868822957085}, 'condition.n.01')": ('trip-n-2',
#               {'trip-n-1': 'change.n.03',
#                'trip-n-2': 'condition.n.01',
#                'trip-n-3': 'happening.n.01',
#                'trip-n-4': 'happening.n.01'}),
#              "({'throw': 0.00040268488995783393, 'stroke': 0.003121181709355186, 'cam_stroke': 0.0006760652677631726, 'the': 0.029296629306008553, 'maximum': 0.00045172803001864695, 'movement': 0.004710180494527928, 'available': 0.00036311168641760125, 'to': 0.006288451272188182, 'a': 0.02285502064915413, 'pivoted': 0.0006760652677631726, 'or': 0.009224425018469361, 'reciprocating': 0.0006170701315741881, 'piece': 0.0012952150376563728, 'by': 0.0030409106758150658, 'cam': 0.0006760652677631726}, 'happening.n.01')": ('stroke-n-2',
#               {'stroke-n-1': 'change.n.03',
#                'stroke-n-10': 'communication.n.02',
#                'stroke-n-2': 'happening.n.01',
#                'stroke-n-3': 'happening.n.01',
#                'stroke-n-4': 'happening.n.01',
#                'stroke-n-5': 'act.n.02',
#                'stroke-n-6': 'number.n.02',
#                'stroke-n-7': 'person.n.01',
#                'stroke-n-8': 'happening.n.01',
#                'stroke-n-9': 'signal.n.01'}),
#              "({'good': 0.006061030258985738, 'goodness': 0.0017383980733691805, 'that': 0.008895928595651525, 'which': 0.0021401369680535236, 'is': 0.009639099185580424, 'pleasing': 0.0013407682233194359, 'or': 0.012769969488109052, 'valuable': 0.002743643068807129, 'useful': 0.0031284591877453506, 'weigh': 0.0015902460131880193, 'the': 0.02583887593120829, 'against': 0.0009541230971688311, 'bad': 0.0014036388148468916, 'among': 0.002317201758077871, 'highest': 0.0011894683926248714, 'goods': 0.0011586008790389355, 'of': 0.023868430333329336, 'all': 0.002256246079263087, 'are': 0.0019950079594345006, 'happiness': 0.0013558351983573446, 'and': 0.0088405495269704, 'self': 0.0010676115247255273, 'realization': 0.0015549218216749851}, 'quality.n.01')": ('goodness-n-1',
#               {'goodness-n-1': 'quality.n.01', 'goodness-n-2': 'good.n.02'}),
#              "({'deny': 0.07232674459981066, 'declare': 0.033445634917071386, 'untrue': 0.03709104263224217, 'contradict': 0.07906491978138347, 'he': 0.010621721793375387, 'denied': 0.07418208526448435, 'the': 0.01673530571915811, 'allegations': 0.04126557163770523, 'she': 0.050628927978972026, 'that': 0.01123888921343629, 'had': 0.015030207188198206, 'taken': 0.025290541827324563, 'money': 0.01940757910038039}, 'disagree.v.01')": ('deny-v-1',
#               {'deny-v-1': 'disagree.v.01',
#                'deny-v-2': 'think.v.03',
#                'deny-v-3': 'keep.v.03',
#                'deny-v-4': 'keep.v.03',
#                'deny-v-5': 'inhibit.v.04',
#                'deny-v-6': 'traverse.v.03'}),
#              "({'seal': 0.05178678954901377, 'seal_off': 0.0370745469418514, 'make': 0.040328586472776796, 'tight': 0.020661650258916132, 'secure': 0.0228903135206617, 'against': 0.01679803818384695, 'leakage': 0.03383932979600387, 'the': 0.043187885726859644, 'windows': 0.025116596716977815}, 'close.v.01')": ('seal-v-1',
#               {'seal-v-1': 'close.v.01',
#                'seal-v-2': 'change.v.01',
#                'seal-v-3': 'decide.v.01',
#                'seal-v-4': 'attach.v.01',
#                'seal-v-5': 'cover.v.01',
#                'seal-v-6': 'get.v.01'}),
#              "({'umbrella': 0.0004095761469362681, 'a': 0.031085043049479864, 'lightweight': 0.0004779795942591339, 'handheld': 0.0005062834091100964, 'collapsible': 0.0005546867544388964, 'canopy': 0.0005546867544388964}, 'artifact.n.01')": ('umbrella-n-1',
#               {'umbrella-n-1': 'artifact.n.01',
#                'umbrella-n-2': 'group_action.n.01',
#                'umbrella-n-3': 'change.n.03'}),
#              "({'offer': 0.0003740794669768201, 'put': 0.0025754772313544244, 'forward': 0.0010812257682686214, 'for': 0.010090371507110146, 'consideration': 0.003964494483651612, 'he': 0.006387449193997797, 'offered': 0.0003704192026138051, 'his': 0.006042359609414828, 'opinion': 0.00131217644660236}, 'think.v.03')": ('offer-v-4',
#               {'offer-v-1': 'supply.v.01',
#                'offer-v-10': 'contend.v.06',
#                'offer-v-2': 'give.v.03',
#                'offer-v-3': 'act.v.01',
#                'offer-v-4': 'think.v.03',
#                'offer-v-5': 'communicate.v.02',
#                'offer-v-6': 'trade.v.01',
#                'offer-v-7': 'offer.v.07',
#                'offer-v-8': 'produce.v.06',
#                'offer-v-9': 'be.v.03'}),
#              "({'elimination': 0.0022281861708797076, 'evacuation': 0.002550289846862528, 'excretion': 0.002794110912149255, 'excreting': 0.002794110912149255, 'voiding': 0.002794110912149255, 'the': 0.02929356592656525, 'bodily': 0.008710837506952127, 'process': 0.028331214529723345, 'of': 0.025765289629385204, 'discharging': 0.002794110912149255, 'waste': 0.001708873157771745, 'matter': 0.00136626364374348}, 'organic_process.n.01')": ('elimination-n-2',
#               {'elimination-n-1': 'separation.n.09',
#                'elimination-n-2': 'organic_process.n.01',
#                'elimination-n-3': 'thinking.n.01',
#                'elimination-n-4': 'separation.n.09'}),
#              "({'involvement': 0.00568286903874072, 'a': 0.02165255731442514, 'connection': 0.009800377251406353, 'of': 0.01987147962666334, 'inclusion': 0.0038120586323167035, 'or': 0.011667799502528211, 'containment': 0.0015392557435679377, 'he': 0.0058040122656658364, 'escaped': 0.0011623941096398141, 'in': 0.00777244861655531, 'the': 0.028151174977583824, 'accident': 0.0008578274437853571, 'there': 0.004545923244375266, 'was': 0.005352988671598287, 'additional': 0.0010427872744102394, 'liver': 0.001136573807748144, 'and': 0.005219324432269063, 'spleen': 0.0015392557435679377}, 'relation.n.01')": ('involvement-n-2',
#               {'involvement-n-1': 'group_action.n.01',
#                'involvement-n-2': 'relation.n.01',
#                'involvement-n-3': 'condition.n.01',
#                'involvement-n-4': 'state.n.02'}),
#              "({'race': 0.0018401849777022361, 'rush': 0.002248719329521815, 'cause': 0.018183353470030594, 'to': 0.01878248989057671, 'move': 0.02093523018379386, 'fast': 0.0014357184256183404, 'or': 0.013393198843312032, 'the': 0.03155940522148704, 'psychologist': 0.0015358993026004684, 'raced': 0.0015358993026004684, 'rats': 0.0014500347281184854, 'through': 0.001986416328962377, 'a': 0.01345806707872455, 'long': 0.0019498893958282027, 'maze': 0.0016827393194690974}, 'move.v.02')": ('rush-v-6',
#               {'rush-v-1': 'travel.v.01',
#                'rush-v-2': 'assail.v.01',
#                'rush-v-3': 'hash_out.v.01',
#                'rush-v-4': 'act.v.01',
#                'rush-v-5': 'travel.v.01',
#                'rush-v-6': 'move.v.02',
#                'rush-v-7': 'make.v.03'}),
#              "({'cope': 0.0016546044537478232, 'get_by': 0.0016546044537478232, 'make_out': 0.0014040773236180001, 'make_do': 0.0018127933047277498, 'contend': 0.0014456265693299469, 'grapple': 0.0016546044537478232, 'deal': 0.004243823919493736, 'manage': 0.0021862313553503996, 'come': 0.0013375388989773748, 'to': 0.013730304828189158, 'terms': 0.0009522015291685758, 'with': 0.00824425686376831, 'we': 0.009342311758826839, 'got': 0.0014300371449313702, 'by': 0.004136016669203959, 'on': 0.005287115881119151, 'just': 0.0011623464027289891, 'a': 0.011379203147501562, 'gallon': 0.0015621036582096617, 'of': 0.0066865125978257285, 'gas': 0.0010239517603528512, 'they': 0.004565036774332429, 'made': 0.0006472305228857777, 'do': 0.004331701536984603, 'half': 0.001062342852369146, 'loaf': 0.0013385516978737342, 'bread': 0.001062342852369146, 'every': 0.001570415927076579, 'day': 0.0012571489903203657}, 'act.v.01')": ('manage-v-3',
#               {'manage-v-1': 'succeed.v.01',
#                'manage-v-2': 'control.v.01',
#                'manage-v-3': 'act.v.01',
#                'manage-v-4': 'control.v.01',
#                'manage-v-5': 'succeed.v.01',
#                'manage-v-6': 'do.v.11',
#                'manage-v-7': 'touch.v.01'}),
#              "({'insensible': 0.11239491682244142, 'unaffected': 0.047688483384311364, 'unaware': 0.05305573496276386, 'of': 0.014193914019045241, 'or': 0.020001942004334076, 'indifferent': 0.044552271834390644, 'to': 0.04908842064514244, 'the': 0.02868909551855676, 'suffering': 0.03920150900562541, 'around': 0.027801879804561568, 'him': 0.022066655919963023}, 'insensitive.a.02')": ('unaffected-a-2',
#               {'unaffected-a-1': 'unaffected.a.01',
#                'unaffected-a-2': 'insensitive.a.02',
#                'unaffected-a-3': 'unmoved.a.01',
#                'unaffected-a-4': 'unaffected.a.04'}),
#              "({'integral': 0.036247278036100006, 'entire': 0.06521486578798054, 'intact': 0.03962418253544972, 'constituting': 0.03457446427366767, 'the': 0.024229305727969053, 'undiminished': 0.023999532707138147, 'entirety': 0.021905273812262364, 'lacking': 0.009801719973695779, 'nothing': 0.012890043624569138, 'essential': 0.013374942975029233, 'especially': 0.00715630379209554, 'not': 0.011014369238941148, 'damaged': 0.01649966174772007, 'a': 0.01633543729731348, 'local': 0.013556075973488095, 'motion': 0.012167303502208331, 'keepeth': 0.023999532707138147, 'bodies': 0.015634309459374267, 'bacon': 0.018123639018050003, 'was': 0.027820637179536343, 'able': 0.012539303495109975, 'to': 0.012756155712890844, 'keep': 0.022631213775369276, 'collection': 0.015634309459374267, 'during': 0.011188256382644366, 'his': 0.007860435895038655, 'lifetime': 0.021905273812262364, 'fought': 0.01736608275679264, 'union': 0.014678070603412993}, 'whole.a.01')": ('integral-a-2',
#               {'integral-a-1': 'intrinsic.a.01',
#                'integral-a-2': 'whole.a.01',
#                'integral-a-3': 'integral.a.03'}),
#              "({'psychology': 0.01528943310494692, 'psychological_science': 0.010945818620927557, 'the': 0.038252127358075684, 'science': 0.04482808105723334, 'of': 0.040373799876395354, 'mental': 0.00568916516929186, 'life': 0.004162428530450045}, 'science.n.01')": ('psychology-n-1',
#               {'psychology-n-1': 'science.n.01'}),
#              "({'secretly': 0.000528327026121382, 'in_secret': 0.0002479100421047009, 'on_the_q': 0.0002479100421047009, 't': 0.004503177201791729, 'on_the_qt': 0.0002479100421047009, 'in': 0.010397044038251535, 'secrecy': 0.00018305474039084286, 'not': 0.0029581780675768023, 'openly': 0.0001761090087071273, 'met': 0.0006122516989995794, 'to': 0.011463847444307064, 'discuss': 0.0009152737019542143, 'the': 0.018800144992531374, 'invasion': 0.00017938792225523985, 'plans': 0.0001430722301280904, 'children': 0.0021262431090480417, 'went': 0.0031933152257113827, 'movies': 0.0004969398086917816, 'when': 0.0017440093944114162, 'they': 0.0049943629248089035, 'were': 0.003257715150728825, 'supposed': 0.00017043797846005534, 'be': 0.004433581565903829, 'at': 0.006748540086965862, 'library': 0.00016564660289726052, 'arranged': 0.00030915080481964117, 'meet': 0.0011052824124700602, 'secret': 0.00014101174643332273}, 'adv.all')": ('secretly-r-1',
#               {'secretly-r-1': 'adv.all', 'secretly-r-2': 'inward.a.01'}),
#              ...})

# %% [markdown]
# ## 切成 9:1 9當 train 1當 test

# %%
split_point = len(featuresets)*9//10
train, test = featuresets[:split_point], featuresets[split_point:]

# %%
from nltk.classify import SklearnClassifier 
from sklearn.linear_model import LogisticRegression
sklearn_classifier = SklearnClassifier(LogisticRegression(C=10e5)).train(train)

# %%
sklearn_classifier
# Out:
# <SklearnClassifier(LogisticRegression(C=1000000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False))>

# %% [markdown]
# ### Non Filter

# %%
import nltk
nltk.classify.accuracy(sklearn_classifier, test)
# Out:
# 0.6310344827586207

# %% [markdown]
# ### Filter

# %%
rank = sklearn_classifier.prob_classify(test[0][0])._prob_dict

# %%
def get_candidates(test_set, raw_data):
    for word, wncat, senseDef, target in raw_data:
        word_tfidf = {}
        word_list = words(senseDef)
        for w in word_list: 
            word_tfidf.update({w: tfidf(w, wncat)})
        if test_set == (word_tfidf, wncat):
            return (word_tfidf, wncat, eval(target))
        else:
            continue

# %%
test[0]
# Out:
# ({'advantages': 0.002972520794449253,
#   'agree': 0.0024282477034199314,
#   'convert': 0.0028870865616447963,
#   'convince': 0.0037274949898293843,
#   'convinced': 0.002814878708749388,
#   'customers': 0.0024583825046658606,
#   'finally': 0.020773334854910272,
#   'had': 0.0011699188297840766,
#   'he': 0.0033070874340455263,
#   'his': 0.005493807357991882,
#   'make': 0.01216397364962673,
#   'of': 0.006874457816791642,
#   'or': 0.011301998220827328,
#   'product': 0.002120206885832057,
#   'realize': 0.0027523517074117218,
#   'several': 0.001629465964695885,
#   'someone': 0.001463261359135597,
#   'something': 0.006027507410228358,
#   'the': 0.016065893490391787,
#   'truth': 0.0040040423799562515,
#   'understand': 0.002063889025054683,
#   'validity': 0.00264791793848511,
#   'win_over': 0.0037274949898293843},
#  'induce.v.02')

# %%
corrections = len(test)
hits = 0
for feature, cat in test:
    output = sklearn_classifier.prob_classify(feature)._prob_dict
    candidates = dict_filter[str((feature, cat))]
    output = [ (ped_cat, prob) for ped_cat, prob in output.items() if ped_cat in candidates[1].values() ]
    if not output: continue
    # candidate 中 最佳的 
    output_class = sorted(output, key=lambda x: x[1], reverse=True)[0][0] # [(cat,prob),(cat,prob)]
    # print(output_class)
    if output_class == cat:
        hits += 1

# %%
print(hits/corrections)
# Out:
# 0.7991379310344827

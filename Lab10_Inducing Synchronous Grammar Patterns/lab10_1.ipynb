# %% [markdown]
# ## 1. preprocessing o.txt -> list

# %%
def create_sentence_pattern_list(input_pat):
    pattern = []
    final = []
    for i in input_pat:
        if i != '':
            pattern.append(i)
        else:
            final.append(pattern.copy())
            pattern.clear()

    # Last one
    final.append(pattern)
    return final

# %%
# English
english_corpus = open('o.txt', 'r').read().strip('\n').split('\n')
english_corpus = create_sentence_pattern_list(english_corpus)

# English correct sentences
english_sent = open('UM-Corpus.en.200k.txt', 'r').read().split('\n')

# %% [markdown]
# - sentence has some wired word

# %% [markdown]
# **eg. abbot âs > ’s**

# %%
for i,obj in enumerate(english_corpus):
    if obj[0] != english_sent[i]:
        obj[0] = english_sent[i]

# %%
# Chinese
chinese_corpus = open('UM-Corpus.ch.200k.tagged.txt', 'r').read().split('\n')

# %%
aligns = open('align.final.200k', 'r').read().split('\n')

# %%
from collections import defaultdict, OrderedDict

# %%
def pattern_pos(sent1, sent2):
    if not isinstance(sent1, list):
        sent1 = sent1.split()

    if not isinstance(sent2, list):
        sent2 = sent2.split()

    if len(sent1) < len(sent2):
        sent1, sent2 = sent2, sent1

    # sent1 is the whole sentence
    # sent2 is the sub sentence

    count = 0
    n = len(sent2)
    for i in range(len(sent1)):
        count = 0
        for j in range(n):
            if sent1[i] == sent2[j]:
                count += 1
                i += 1
                if count == n:
                    return (i - n, i)
            else:
                i -= count
                break
    return (-1, -1)

# %%
#from orderedset import OrderedSet

# %% [markdown]
# - 從 UM-Corpus.ch.200k.tagged.txt 取出 中文文法

# %%
def extract_ch_grammar(ch_pat):
    ch_grammar = ch_pat.split(' ')
    ch_grammar = [cg.split('_')[1] for cg in ch_grammar if '_' in cg]
    ch_grammar = [cg for cg in ch_grammar if cg == 'V' or cg == 'P' or cg == 'N']
    
    if ch_grammar == ['V', 'V']:
        ch_grammar = 'V v'
    else:
        #ch_grammar = OrderedSet(ch_grammar)
        ch_grammar = ' '.join(ch_grammar).lower().replace('v', 'V')

    return ch_grammar

# %% [markdown]
# - 計算 english grammar -> chinese grammar 的次數
#     - noisy_channel[en_gram][ch_gram] = list(en_sen->ch_sen pair)

# %%
import re
def extract_pattern():
    count = 0
    noisy_channel = defaultdict(lambda: defaultdict(list))
    for english, chinese, align in zip(english_corpus, chinese_corpus, aligns):
        count += 1
        en_sent = english[0].split()
        ch_sent = chinese.split()
        align = align.split()
        en_ch = OrderedDict()
        index = 0

        try:
            for a in align:
                en_pos, ch_pos = a.split('-')
                en_pos = int(en_pos)
                ch_pos = int(ch_pos)
                en = en_sent[en_pos]
                ch = ch_sent[ch_pos]
                en_ch[index, en_pos, en] = ch
                index += 1

            for _ in english[1:]:
                _, en_grammar, en_pat = _.split('\t')
                en_grammar = re.sub('about|in|on|to|for|with', 'p', en_grammar)
                start, end = pattern_pos(en_sent, en_pat)
                ch_pat = ""
                for en, ch_term in en_ch.items():
                    _, en_pos, en_term = en
                    if en_pos >= start and en_pos < end:
                        ch_pat += "%s " % ch_term
                    elif en_pos >= end:
                        break
                if 'V' in ch_pat:
                    ch_grammar = extract_ch_grammar(ch_pat)
                    noisy_channel_pattern = "%s | %s" % (en_pat, ch_pat)
                    noisy_channel[en_grammar][ch_grammar].append(noisy_channel_pattern)

        except Exception as e:
            print("line %d: %s" % (count, str(e)))
    return noisy_channel

# %%
en_ch_pat = extract_pattern()
# Out:
# line 166219: list index out of range
# line 180500: list index out of range
# line 180503: list index out of range
# line 186533: list index out of range
# line 199209: list index out of range

# %%
import math
import operator
from pprint import pprint

PRONS = set([line.strip('\n') for line in open('prons.txt')])

with open('HiFreWords') as f:
    HiFreWords = set(f.readline().split('\t'))

def compute_score(word, sent):
    global PRONS
    global HiFreWords

    word = word.lower()
    sent = sent.lower().split()
    length = len(sent)

    locationOfWord = -1 if word not in sent else sent.index(word)
    hiFreWordsScore = len([w for w in sent if w not in HiFreWords])
    pronsScore = len([w for w in sent if w in PRONS])

    return locationOfWord - hiFreWordsScore - pronsScore

# %%
def get_pattern(input_pat):
    _sum = 0
    stddev = 0.0
    k0 = 0.5

    N = len(en_ch_pat[input_pat])
    if N == 0:
        return "NO RESULT"
    
    for k, v in en_ch_pat[input_pat].items():
        _sum += len(v)
    avg = _sum / N

    print("%s (%d)" % (input_pat, _sum))

    for k, v in en_ch_pat[input_pat].items():
        stddev += (len(v) - avg) ** 2
    stddev = math.sqrt(stddev / N - 1)
    
    final_result = {}
    
    # Filter good grammar
    for grammar, sentences in en_ch_pat[input_pat].items():
        best_sentences = [(-999.9,''), (-999.9,''), (-999.9,'')]
        freqi = len(sentences)
        strength = (freqi - avg) / stddev
        if not strength > k0:
            continue

        # Find Good Dictionary Example
        for sentence in sentences:
            score = compute_score(input_pat, sentence)
            if score > best_sentences[0][0]:
                best_sentences.pop(0)
                best_sentences.append((score, sentence))
                best_sentences.sort()

        final_result[(grammar, freqi)] = best_sentences

    # Print the result
    for key in sorted(final_result, key=lambda x: x[1], reverse=True):
        values = final_result[key]
        print('-> %s (%d)' % (key[0], key[1]))
        for value in values:
            en, ch = value[1].split(" | ")
            print('     %s %s' % (en, ch))

# %%
get_pattern('V n')
# Out:
# V n (121119)
# -> V n (26889)
#      authorized me 授權_V 我_N
#      keeping abreast 與時俱進_V 國際_N
#      leave any fingerprints 留下_V 指紋_N
# -> V (13617)
#      adore everything 崇拜_V
#      be an aggregate 服務_V
#      constitute a crime 構成_V
# -> V v (10849)
#      controlling aspects 上癮_V 上癮_V
#      explain everything 說明_V 詳細_V
#      give directions 指路_V 指路_V
# -> V n n (10192)
#      buy insurance 買_V 保險_N 保險_N
#      decrease body fat 減少_V 脂肪_N 脂肪_N
#      don aboriginal dress 穿上_V 土著_N 居民_N
# -> V V n (8953)
#      has abundant experience 擁有_V 豐富_V 經驗_N
#      having a love 有_V 有_V 愛_N
#      helped anchor Asia 幫助_V 掌握_V 亞洲_N
# -> V V V (3600)
#      is a master 是_V 是_V 貼切_V
#      is gaining extensive attention 受到_V 廣泛_V 重視_V
#      make a house call 浴_V 出診_V 出診_V
# -> n V (3188)
#      has clinical importance 糖尿病_N 重要_V
#      have access 他們_N 訪問_V
#      have control 你_N 控制_V
# -> n V n (2719)
#      be an administrator 管理員_N 冒充_V 管理員_N
#      became a citizen 奧巴馬_N 加入_V 印尼_N
#      have both 你們_N 需要_V 你們_N
# -> V V n n (2628)
#      do detailed bookkeeping 進行_V 詳細_V 簿記_N 工作_N
#      does have air conditioning 是_V 有_V 空調_N 空調_N
#      like learning foreign languages 想_V 學_V 外語_N 外語_N
# -> V n V (2533)
#      include abdominal discomfort 包括_V 腹部_N 不適_V
#      involves a code change 涉及到_V 程式碼_N 更改_V
#      make a difference 有所_V 作為_N 有所_V
# -> n (2485)
#      be coal 永遠_ADV 煤炭_N
#      can detect evidence 可以_ADV 跡象_N
#      held me 不只_ADV 我_N
# -> V n n n (2409)
#      buy large agricultural machinery 購買_V 大型_N 農業_N 機械_N
#      hang epitaphs 懸掛_V 墓誌銘_N 槓架_N 結構_N
#      keeping kids 使_V 孩子_N 們_N 學校_N
# ->  (2260)
#      applying levels 將_ADV
#      can keep house 會_ADV
#      have an account 得_ADV
# -> V V V n (2041)
#      are a common cause 是_V 是_V 常見_V 原因_N
#      has a marked influence 有_V 有_V 顯著_V 影響_N
#      have a distinct advantage 有_V 有_V 明顯_V 優勢_N
# -> n V V (1153)
#      getting a date 瑪麗_N 約會_V 約會_V
#      initiate criminal action 刑事_N 訴訟_V 提起_V
#      make a call 你_N 大_V 需要_V
# -> V n V n (1089)
#      avoid color changing 防止_V 顏色_N 發生_V 變化_N
#      gives a different answer 給出_V 主教_N 不同於_V 答案_N
#      has been a center 成為_V 奧克蘭_N 成為_V 中心_N
# -> n n (1082)
#      felt hat 常_ADV 禮帽_N 圓頂_N
#      have fun 不必_ADV 娛樂_N 款_N
#      is advantage 尚_ADV 隱士_N 好處_N
# -> n n V (988)
#      Blood gases analysis 血氣_N 血氣_N 分析_V
#      assign events 歷史_N 事件_N 發生_V
#      burn down houses 州官_N 州官_N 放火_V
# -> p V n (956)
#      came form France 從_P 寄來_V 法國_N
#      has lost confidence 被_P 失去_V 信心_N
#      laid back its ears 向_P 收_V 兩耳_N
# -> n V n n (881)
#      are called electronic effect 電子_N 總稱為_V 電子_N 效應_N
#      boost domestic demand 措施_N 促進_V 內需_N 內需_N
#      detailing actual expenditure 預算_N 實際_V 情況_N 支出_N
# -> V V V V (864)
#      helps keep down floods 有助於_V 有助於_V 制止_V 制止_V
#      keep a man awake 使_V 不成_V 寐_V 寐_V
#      make an important decision 作出_V 重要_V 重要_V 決定_V
# -> p V (829)
#      be choose 被_P 選拔出_V
#      be hand 被_P 勾結_V
#      cover increase 用_P 提高_V
# -> V p n (783)
#      committed a breach 犯_V 在_P 罪_N
#      is drinking himself 喝_V 把_P 自己_N
#      is hand 是_V 用_P 手工_N

# %%
get_pattern('V p n')
# Out:
# V p n (27246)
# -> V n (2379)
#      is manufactured in China 單挑_V 中國_N
#      lay for hours 長_V 時間_N
#      listen for frogs 傾聽_V 蛙鳴_N
# -> V V n (2160)
#      calling for elections 體面_V 舉行_V 選舉_N
#      intend for me 打算_V 讓_V 我_N
#      look for an apartment 指望_V 是_V 公寓_N
# -> V (1793)
#      is in conformity 符合_V
#      keep in check 努力_V
#      know for a certainty 知道_V
# -> V v (1649)
#      be in charge 主導_V 主導_V
#      be in charge 負責_V 負責_V
#      be in line 適合_V 適合_V
# -> V n n (1199)
#      are in charge 是_V 負責人_N 負責人_N
#      fall in love 墜入_V 愛河_N 愛河_N
#      is for defence 是_V 費用_N 國防_N
# -> V V V (1100)
#      ask for compensation 要求_V 賠償_V 賠償_V
#      be found in certain degrees 奢_V 惰_V 惰_V
#      go in for expansion 搞_V 搞_V 擴張_V
# -> V V n n (993)
#      applied for college admission 申請_V 申請_V 大學_N 大學_N
#      look for a job 尋找_V 尋找_V 工作_N 工作_N
#      looking for a bone 翻找_V 翻找_V 骨頭_N 骨頭_N
# -> V p n (775)
#      buy in China 買_V 在_P 中國_N
#      live in London 住_V 在_P 倫敦_N
#      lived in Canada 住_V 在_P 加拿大_N
# -> V V V n (771)
#      are in love 是_V 愛上_V 愛上_V 她_N
#      coming in an idea 進來_V 進來_V 有_V 意見_N
#      live in a house 住_V 住_V 向陽_V 房子_N
# -> n V (658)
#      are in error 他們_N 錯_V
#      calling for elections 大選_N 體面_V
#      had for keeps 他_N 永遠_V
# -> n V n (585)
#      are in good condition 狀況_N 良好_V 狀況_N
#      had asked for directions 他_N 問_V 一下路_N
#      is in good condition 狀況_N 良好_V 狀況_N
# -> V n n n (391)
#      ask for an explanation 問_V 一下_N 一下_N 一下_N
#      has been made in highway infrastructure construction 實現_V 公路_N 基礎_N 設施_N
#      have been measured in fractions 是_V 公制_N 公制_N 公制_N
# -> n (390)
#      head for his gardens 直_ADV 花園_N
#      is not imposed in accordance 依據_N 不_ADV
#      does gather in groups 也_ADV 結群_N
# -> V V V V (370)
#      analysed in company 相與_V 析_V 析_V 析_V
#      ask for a loan 忍辱_V 告貸_V 告貸_V 告貸_V
#      ask for an appointment 請求_V 請求_V 約見_V 約見_V
# -> V n V (324)
#      allows for a cancellation 允許_V 生_N 取消_V
#      believed in freedom 相信_V 言論_N 自由_V
#      go for high education 去_V 中學_N 畢業_V
# -> V p n n (317)
#      happens in a flash 發生_V 在_P 一瞬間_N 一瞬間_N
#      is distributed in human lungs 分佈_V 在_P 人體_N 肺部_N
#      like about China 喜歡_V 對於_P 中國_N 中國人_N
# -> n V V (311)
#      am in charge 我_N 負責_V 負責_V
#      apply for admission 留學生_N 入學_V 入學_V
#      are in collusion 他們_N 串通_V 串通_V
# ->  (284)
#      failing in duty 不_ADV
#      held for me 會_ADV
#      is in fact 是否_ADV
# -> V V n V (249)
#      care for hot food 喜歡_V 辣_V 味兒_N 辣_V
#      involved in malicious collusion 參與_V 參與_V 惡意_N 串通_V
#      looking for food 找_V 找_V 食_N 吃_V
# -> n n (242)
#      get to California 多久_N 要_ADV 加利福尼亞_N
#      have for dessert 還_ADV 甜點_N 決定_N
#      lay about her 她_N 就_ADV 她_N
# -> V V V n n (241)
#      used for a board game 種_V 用作_V 用作_V 棋盤_N 遊戲_N
#      is encapsulated in a dynamic library 進行_V 封裝_V 生成_V 動態庫_N 動態庫_N
#      lies in context 在於_V 在於_V 施_V 事_N 功能_N
# -> n V n n (241)
#      soared in April 宅_N 高漲_V 四月_N 四月_N
#      falls in Africa 瀑布群_N 大_V 非洲_N 瀑布群_N
#      feature for Brazil 巴西_N 出戰_V 巴西_N 巴西_N
# -> V V n n n (234)
#      lie down for a while 躺_V 躺_V 一下_N 一下_N 一下_N
#      lie down for a while 躺下_V 躺下_V 一會兒_N 一會兒_N 一會兒_N
#      is in Arlington 位於_V 位於_V 弗吉_N 尼亞州_N 阿林頓_N
# -> n n V (223)
#      ask for an extension 你們_N 時間_N 寬限_V
#      asked for details 詳情_N 詳情_N 噤若寒蟬_V
#      is in consequence 市場_N 市場_N 忽起忽落_V
# -> n V V n (216)
#      could be expressed in high yield 痘苗_N 真_V 表達_V 核_N
#      has gone to Europe 他_N 去_V 去_V 歐洲_N
#      have majored in accounting 我_N 主修_V 主修_V 會計_N
# -> p V n (211)
#      is in good shape 在_P 好_V 腿傷_N
#      may be couched in that kind 用_P 聽慣_V 字眼_N
#      take for a letter 往_P 寄_V 信_N
# -> V n V n (210)
#      has on display artifacts 展出_V 文物館_N 展出_V 泰雅族_N
#      alternate in direction 回轉_V 方向_N 回轉_V 方向_N
#      cleared for ILS approach 允許_V 盲降進_N 近_V 盲降進_N
# -> V p (198)
#      appear in front 出現_V 在_P 前面_Loc
#      keep in check 保留_V 在_P 檢查_Nv
#      was in bed 是_V 在_P
# -> p V (179)
#      asked for money 向_P 討錢_V
#      comes in handy 時_POST 在_P 派上用場_V
#      ask for advice 向_P 請教_V
# -> V V V V n (170)
#      fit for modern CCM 適合_V 適合_V 現代_V 測評_V 體系_N
#      are destined for disaster 註定_V 是_V 註定_V 註定_V 災難_N
#      is in a critical condition 處於_V 處於_V 危急_V 危急_V 狀況_N
# -> V V p n (168)
#      were born in fall 出生_V 出生_V 在_P 秋天_N
#      avoid living in areas 避免_V 居住_V 在_P 發區_N
#      like living in Canada 喜歡_V 住_V 在_P 加拿大_N
# -> V p V n (165)
#      focused on business 專注_V 於_P 專注_V 業務_N
#      is in constant motion 是_V 在_P 不斷_V 運動_N
#      lives in a free country 生活_V 在_P 的_DE 自由_V 國家_N
# -> V p p n (156)
#      grew up in Beijing 長_V 在_P 在_P 北京_N
#      begins in February 開始_V 於_P 於_P 二月_N
#      lies in its history 根植_V 於_P 於_P 歷史_N
# -> p n (152)
#      being in heaven 就_ADV 在_P 天堂_N
#      dig out about Global 一起_ADV 關於_P 全球_N
#      is in China 正_ADV 在_P 中國_N
# -> n V V V (143)
#      are calling for cuts 們_N 要求_V 要求_V 減稅_V
#      does in fact 它_N 實際_V 實際_V 是_V
#      go looking for happiness 你_N 追尋_V 苦苦_V 幸福_V
# -> V p V (138)
#      fall in love 喜歡上_V 在_P 喜歡上_V
#      let in light 讓_V 在_P 輕_V
#      living in groups 群居_V 於_P 群居_V
# -> p n V (138)
#      are in agreement 對_P 看法_N 一致_V
#      be determined in accordance 按照_P 國家_N 有關_V
#      dies in a heart attack 在_P 心臟病_N 發作_V
# -> n n V n (137)
#      arising in patients 息肉症_N 患者_N 發生_V 患者_N
#      can excel in the construction 建設_N 建設_N 作出_V 建設_N
#      flowing in computer open laboratory 人員_N 計算機_N 開放_V 實驗室_N
# -> p V V n (132)
#      look for a location 來_ADV 為了_P 是_V 選擇_V 地點_N
#      are asking for food 在_P 尋求_V 尋求_V 糧食_N
#      interested in literature 對_P 感興趣_V 感興趣_V 文學_N
# -> p V V (110)
#      can be keep in custody and charge 對_P 看守_V 控告_V
#      can is keep in custody and charge 對_P 看守_V 控告_V
#      is designed for the hidden 被_P 設計為_V 躲_V
# -> V V V V V (101)
#      've been in good health 別來無恙_V 別來無恙_V 別來無恙_V 別來無恙_V 別來無恙_V
#      ballot for a strike 投票_V 為_V 為_V 罷工_V 進行_V
#      felt completely left out in cold 覺得_V 冷落_V 冷落_V 冷落_V 冷落_V
# -> V V n V n (97)
#      can contribute to a well balanced diet 有利於_V 有利於_V 桔子_N 均衡_V 飲食_N
#      used for grinding 用來_V 用來_V 砂輪_N 打磨_V 打光_N
#      acting on behalf 代表_V 代表_V 公司_N 做_V 事_N
# -> V n n n n (95)
#      is excited about Google Glass 是_V 約翰_N 辛普森_N ·_。 辛普森_N 辛普森_N
#      looked for a long time 看_V 長期_N 長期_N 長期_N 長期_N
#      stray for a bit 鬼混_V 一段_N 一段_N 一段_N 時間_N
# -> V n n V (90)
#      make for efficient cooking 的_DE 高_V 效率_N 妙訣_N 烹調_V
#      arrived in London 到_V 倫敦_N 倫敦_N 求學_V
#      develop in depth 縱深_V 發展_N 發展_N 縱深_V
# -> V n V V (89)
#      come down to assumptions 歸結到_V 我們_N 歸結到_V 假設_V
#      hear about our fund 聽說_V 我們_N 年輕_V 集資_V
#      wash in a bath 洗_V 盆_N 浴_V 浴_V
# -> p V p n (89)
#      sold in capsules 以_P 販賣_V 以_P 膠囊_N
#      be ascending in academia 在_P 升遷_V 在_P 學術界_N
#      cooperate in areas 諸如_P 合作_V 在_P 領域_N
# -> n n n (85)
#      go for long periods 可以_ADV 長期_N 長期_N 長期_N
#      is in Paris 他_N 正在_ADV 巴黎_N 巴黎_N
#      still going in circles 一_ADV 進展_N 進展_N 進展_N
# -> p V n n (84)
#      be built in the vicinity 在_P 新建_V 附近_N 排汙口_N
#      is placed in a container 將_P 中_POST 放入_V 材料_N 容器_N
#      lies in its management or administration 主要_ADV 在_P 經營_V 管理_N 管理_N
# -> p n n (83)
#      fit in our hand 可以_ADV 在_P 我們_N 手_N
#      has worked for me 已經_ADV 在_P 方法_N 我_N
#      be in an era 能_ADV 在_P 時代_N 時代_N
# -> n p V (78)
#      was in despair 他_N 對_P 絕望_V
#      Egypt in exchange 埃及_N 以_P 換取_V
#      is in charge 目前_N 在_P 負責_V
# -> n V V n n (76)
#      are looking for investors 目前_N 正在_ADV 尋找_V 尋找_V 投資_N 者_N
#      is also involved in legal action ShapardFairey_FW 同時_N 捲入_V 捲入_V 美聯社_N 美聯社_N
#      lies in a coma 暈迷_N 陷入_V 陷入_V 暈迷_N 狀態_N
# -> V n V n n (72)
#      is in the Ivory Coast 是_V 幾點鐘_N 是_V 象牙海岸_N 象牙海岸_N
#      specialize in business law 專攻_V 商法_N 專攻_V 商法_N 商法_N
#      ask for a loan 詢問_V 一下_N 詢問_V 一下_N 貸款_N
# -> p (72)
#      are emerging in multitude 正在_ADV 在_P
#      can be made in conjunction 可_ADV 可_ADV 連同_P
#      am in charge 不_ADV 在_P
# -> n V n V (70)
#      are based on conditions 團體_N 兼_V 總裁_N 兼_V
#      falls in love 愛火_N 熾熱_V 的_DE 愛火_N 燃燒_V
#      was in great disorder 朝綱_N 混亂_V 朝綱_N 混亂_V
# -> n V p n (70)
#      are gathered in Geneva 們_N 聚集_V 在_P 日內瓦_N
#      do in Afghanistan 事情_N 做_V 在_P 阿富汗_N
#      is based in Geneva 總部_N 設_V 在_P 日內瓦_N
# -> n n n V (68)
#      descirbed in Design Electronics 專案_N 產品_N 電子_N 這樣子_V
#      has been implicated in researches 恩樣_N 恩樣_N 丘疹病_N 研究_V
#      scientifically based in comparison 中醫_N 科學_N 依據_N 相比_V
# -> V p n n n (68)
#      lived in Arbat 居住_V 在_P 阿爾_N 巴特_N 大街_N
#      met in May 相遇_V 在_P 月份_N 五_N 月份_N
#      were in African countries 是_V 在_P 撒哈拉_N 非洲_N 國家_N
# -> p p V (67)
#      asks for advice 向_P 向_P 請教_V
#      be in control 在_P 在_P 控制_V
#      is in drop 在_P 在_P 下降_V
# -> V V p n n (67)
#      is built on high ground 是_V 建_V 於_P 高處_N 高處_N
#      know about the evolution 知道_V 知道_V 從_P 發展_N 過程_N
#      was born in Denmark 出生_V 出生_V 在_P 丹麥_N 丹麥人_N
# -> V V V n V (67)
#      can lead to liver damage 導致_V 導致_V 導致_V 肝_N 損傷_V
#      is located in Anji County 位於_V 位於_V 位於_V 電站_N 位於_V
#      listen to me 聽_V 聽_V 講話_V 我_N 好不好_V
# -> V n p n (65)
#      do for me 做_V 事_N 為_P 的_DE 我_N
#      happens in Afghanistan 發生_V 事情_N 在_P 的_DE 阿富汗_N
#      offer are designed in Germany 提供_V 設計_N 在_P 德國_N
# -> n p n V (63)
#      being in Milwaukee 密爾沃基_N 在_P 密爾沃基_N 打球_V
#      ends in May 五月_N 在_P 五月_N 到期_V
#      fighting for freedom 戰_N 為_P 自由_N 視死如歸_V
# -> n V n n n (63)
#      based on characters projection distance 車牌_N 進行_V 字元_N 投影_N 距離_N
#      speak to Jim Jones 英語_N 找_V 吉姆_N 瓊斯_N 先生_N
#      align with blue line 杆_N 對準_V 杆_N 藍線_N 藍線_N
# -> p n n V (61)
#      cash in on me 在_P 身_N 上_Loc 我_N 討便宜_V
#      explain in detail 對_P 解釋_N 境_N 內_Loc 詳細_V
#      was investigated for extraction 在_P 萬壽_N 菊_N 提取_V
# -> p p n (60)
#      be built in hull bottom 將_ADV 在_P 在_P 船體_N 底部_Loc
#      be in the hands 都_ADV 在_P 在_P 手_N
#      can have according to experts 可以_ADV 根據_P 根據_P 專家_N
# -> V V n n V (59)
#      converting to an environmentally friendly industry 善待_V 善待_V 環境_N 環境_N 是_V
#      go backpacking in India 去_V 揹包_V 印度_N 印度_N 旅行_V
#      lead to analytic geometry 導致_V 瞭_V 解析幾何_N 解析幾何_N 產生_V
# -> V p n V (59)
#      depend for recovery 依賴_V 於_P 經濟_N 復甦_V
#      goes for career choice 也_ADV 適合_V 於_P 職業_N 選擇_V
#      is about the definition 是_V 對_P 模特_N 作_V
# -> V p p n n (58)
#      die in traffic accidents 死_V 於_P 於_P 交通_N 事故_N
#      embedded in the entertainment 嵌_V 在_P 在_P 娛樂_N 活動_N
#      live in a cloud forest 居住_V 在_P 在_P 哥斯大黎加_N 林_N
# -> p p V n (57)
#      are in trouble 在_P 在_P 遇到_V 困難_N
#      has in store 在_P 在_P 主宰_V 命運_N
#      join with me 跟_P 跟_P 合夥_V 我_N
# -> V V n n n n (56)
#      persist for a long time 迷惑_V 存在_V 長期_N 長期_N 長期_N 長期_N
#      apply for American graduate schools 申請_V 申請_V 美國_N 研究所_N 研究所_N 美國_N
#      will be felt for countless generations 澤及_V 澤及_V 萬_N 萬_N 萬_N 世_N
# -> n V V V n (54)
#      come up in the distance 遠方_N 升起_V 升起_V 升起_V 遠方_N
#      am going for a hike 我_N 打算_V 去_V 去_V 洛磯山脈_N
#      came to an accord 他們_N 達成_V 達成_V 達成_V 協議_N
# -> n p V n (54)
#      means to me 意義_N 對_P 提問_V 我_N
#      was in charge 他_N 在_P 負責_V 全國_N
#      are given for experiments 清漆_N 為_P 提供_V 實驗_N
# -> n n V V (52)
#      was established for determination 庫侖法_N 庫侖法_N 測定_V 測定_V
#      gets going about himself 勁頭_N 勁頭_N 談_V 十足_V
#      is described in detail 演算法_N 描述_N 詳細_V 詳細_V
# -> V V V n n n (52)
#      asks for a host internal Goldman documents 要求_V 要求_V 提供_V 一_DET 系列_N 與_C 高盛_N 檔案_N
#      engages in a private military action 從事_V 從事_V 從事_V 祕密_N 軍事_N 行動_N
#      specialized in construction machinery business 專業_V 從事_V 從事_V 工程_N 機械_N 業務_N
# -> V p V V (51)
#      are seen in full bloom 看到_V 在_P 盛開_V 盛開_V
#      go in for swimming 沉迷_V 於_P 游泳_V 游泳_V
#      beg for a living 乞討_V 以_P 為生_V 為生_V
# -> V p V n n (50)
#      implicit in ethnic differences 加深_V 於_P 隱藏_V 民族_N 差別_N
#      is for children 是_V 為了_P 讓_V 孩子_N 們_N
#      locate in Hong Kong 定居_V 在_P 定居_V 香港_N 香港_N
# -> V V V V n n (49)
#      dealing with liquid waste 處理_V 火炸_V 處理_V 火炸_V 藥廠_N 廢水_N
#      is located in the Sahel area 位於_V 位於_V 位於_V 位於_V 薩赫勒_N 地區_N
#      give to a grand jury 交給_V 交給_V 大_V 大_V 陪審團_N 一覽表_N
# -> n p n (48)
#      been Aled in Asia 已經_ADV 亞洲_N 在_P 亞洲_N
#      had been in Canaan 迦南_N 已_ADV 在_P 迦南_N
#      is licensed in accordance 已經_ADV 牌照_N 按照_P 獲發_N
# -> p p n V (47)
#      add in the meat 把_P 把_P 肉_N 放進去_V
#      are in constant awe 在_P 在_P 人_N 敬畏_V
#      go to a jazz concert 到_P 到_P 爵士樂_N 聽_V
# -> V p p (46)
#      applied for it 申請_V 為_P 為_P
#      look for a place 找_V 替_P 替_P
#      are defined in accordance 劃定_V 依照_P 依照_P
# -> V n V V n (45)
#      was formed in Mesozoic era 形成_V 裂_N 陷_V 陷_V 盆地_N
#      believe in pure friendship 相信_V 男女_N 存在_V 純潔_V 友情_N
#      hurdle to London 克服_V 困難_N 克服_V 到達_V 倫敦_N
# -> V V n V V (44)
#      called for the opening 呼籲_V 呼籲_V 對話_N 開啟_V 開啟_V
#      leading to the Great Depression 導致_V 導致_V 一_N 大_V 蕭條_V
#      speak about any alliance 提_V 續絃_V 的_DE 事_N 續絃_V 續絃_V
# -> p n V n (42)
#      are working for chicken feed 在_P 小錢_N 為_V 而_C 小錢_N
#      go for this job 就_P 寄份_N 給_V 這_DET 工作_N
#      is done in lossy media 對_P 媒質_N 進行_V 媒質_N
# -> n V V V V (41)
#      is made for absence 病_N 請假_V 請假_V 請假_V 不_ADV 扣_V
#      ask for an Increase 臉皮_N 要求_V 要求_V 增加_V 增加_V
#      ask for an increase 臉皮_N 要求_V 要求_V 增加_V 增加_V
# -> p V V n n (39)
#      can apply for a local hukou 可_ADV 憑_P 申請_V 申請_V 畢業證_N 學位證_N
#      talk about it 和_P 討論_V 討論_V 一下_N 一下_N
#      comment for this article 對_P 置評_V 置評_V 本文_N 本文_N
# -> V V p (38)
#      insist on the difference 堅持_V 堅持_V 把_P
#      fronting for a gang 偽造_V 偽造_V 一_ADV 幫_P
#      is in addition 是_V 附加_V 在_P
# -> V V p V (35)
#      go to extremes 去_V 去_V 為了_P 極端_V
#      calls for a ban 呼籲_V 呼籲_V 在_P 禁_V
#      have demonstrated in front 阻止_V 干預_V 以_P 阻止_V
# -> p p V V (35)
#      are in full bloom 在_P 在_P 怒放_V 怒放_V
#      are in full bloom 在_P 在_P 怒放_V 怒放_V
#      ended in a blood bath 以_P 以_P 大屠殺_V 收場_V
# -> n V p n n (35)
#      be wrapped in kraft paper 木箱_N 裝入_V 在_P 牛皮紙_N 牛皮紙_N
#      pitching to consumers 消費者_N 推銷_V 向_P 消費者_N 產品_N
#      signalled to me 身邊_N 示意_V 到_P 我_N 我_N
# -> p p n n (34)
#      go to the beach 到_P 去_ADV 到_P 海灘_N 海灘_N
#      had come to my house 曾_ADV 到_P 到_P 我_N 家_N
#      is based on notional figures 尚_ADV 根據_P 根據_P 數字_N 數字_N
# -> p V p n n (33)
#      are employed in many electronic companies 受_P 僱_V 於_P 許多_DET 電子_N 公司_N
#      are in Guangzhou 在_P 住_V 在_P 廣州_N 白雲_N
#      is concentrated in dollar assets 於_P 集中_V 於_P 美元_N 資產_N
# -> p V V V (33)
#      was charged with arson 被_P 控_V 控_V 縱火_V
#      went for a song 都_ADV 以_P 廉價_V 廉價_V 出售_V
#      are fighting for survival 在_P 為_V 為_V 生存_V
# -> V V p p n (32)
#      closely associated with adhesion 緊緊_V 相連_V 與_P 與_P 分子_N
#      is mainly based on agriculture 為主_V 為主_V 以_P 以_P 農業_N
#      like living in a village 喜歡_V 住_V 在_P 在_P 鄉村_N
# -> V V V n V n (32)
#      go for medical examinations and exercises 作_V 進行_V 作_V 體檢_N 檢查_V 和_C 運動_N
#      is preparing for general elections 顯示_V 顯示_V 投資_V 者_N 擔心_V 肯亞_N
#      engage in international communications 從事_V 敲響_V 從事_V 國際_N 交流_V 警鐘_N
# -> V n n V n (30)
#      are based on authentic materials 這些_DET 為_V 基礎_N 基礎_N 真實_V 材料_N
#      depend on support 提供_V 軍事_N 需要_N 提供_V 支援_N
#      went for a sail 去_V 羅期塞_N 羅期塞_N 度假_V 羅期塞_N
# -> p V V V n (30)
#      has been looking for a job 在_P 已經_ADV 已經_ADV 找_V 找_V 有_V 工作_N
#      shift for themselves 自_P 謀_V 謀_V 謀_V 生活_N
#      are looking for ways 在_P 尋找_V 尋找_V 回擊_V 方法_N
# -> n n V V n (30)
#      is distended with fluid 心音_N 心音_N 減弱_V 充滿_V 液體_N
#      is situated in Qionghai 博鰲_N 博鰲_N 位於_V 位於_V 瓊海_N
#      has also asked for a commission 祖瑪_N 祖瑪_N 要求_V 要求_V 委員會_N
# -> n p n n (30)
#      worked in a company 工作_N 在_P 一_ADV 家_N 公司_N
#      would gradually disappear in favor 逐漸_ADV 自由市_N 被_P 場所_N 自由市_N
#      applies for a credit card 人_N 為了_P 會_ADV 信用卡_N 信用卡_N
# -> p V n n n (28)
#      can write in literary language 會_ADV 用_P 寫_V 文章_N 文學_N 語言_N
#      related to liquid waste disposal 關於_P 清理_V 液體_N 垃圾_N 垃圾_N
#      has been in prison 對_P 有_V 過_ASP 牢_N 牢_N 偏見_N
# -> p V n V (27)
#      turned in the lock 把_P 插進_V 鎖孔_N 插進_V
#      are held in fairly high esteem 對_P 是_V 同志_N 比較_ADV 尊重_V
#      lunged for me 向_P 撲過來_V 我_N 撲過來_V
# -> p p (27)
#      hang to anything 把_P 把_P 非_ADV
#      shall be completed in accordance 按照_P 必須_ADV 按照_P
#      was in line 很_ADV 在_P 在_P
